# %% [markdown]
# <center>
# <img src="https://laelgelcpublic.s3.sa-east-1.amazonaws.com/lael_50_years_narrow_white.png.no_years.400px_96dpi.png" width="300" alt="LAEL 50 years logo">
# <h3>APPLIED LINGUISTICS GRADUATE PROGRAMME (LAEL)</h3>
# </center>
# <hr>

# %% [markdown]
# # Corpus Linguistics - Study 1 - Phase 5 - INRS

# %% [markdown]
# ## Required Python packages

# %% [markdown]
# - pandas

# %% [markdown]
# ## Importing the required libraries

# %%
from dotenv import load_dotenv
import openai
import re
import pandas as pd
import os
import sys
import json
import logging
from tqdm import tqdm
import time

# %% [markdown]
# ## Defining input variables

# %%
input_directory = 'cl_st1_ph4_examples'
input_directory_anova = 'cl_st1_inrs_anova'
output_directory = 'cl_st1_ph5_inrs'

# %% [markdown]
# ## Creating output directory

# %%
# Check if the output directory already exists. If it does, do nothing. If it doesn't exist, create it.
if os.path.exists(output_directory):
    print('Output directory already exists.')
else:
    try:
        os.makedirs(output_directory)
        print('Output directory successfully created.')
    except OSError as e:
        print('Failed to create the directory:', e)
        sys.exit(1)
# Out:
# Output directory successfully created.

# %% [markdown]
# ## Creating a dictionary that relate the `Dimension-Pole` pair with the `Text ID`s of the respective examples

# %%
# Dictionary to store the parsed data with string keys
dimension_examples = {}

# RegEx pattern to extract Text ID
text_id_pattern = re.compile(r'file = (t\d{6})')

# Mappings for 'Dimension' and 'Pole'
dimension_mapping = {
    'f1': 'Dimension 1',
    'f2': 'Dimension 2',
    'f3': 'Dimension 3',
    'f4': 'Dimension 4',
    'f5': 'Dimension 5',
    'f6': 'Dimension 6'
}

pole_mapping = {
    'neg': 'Negative Pole',
    'pos': 'Positive Pole'
}

# Getting the list of files and sorting them
files = sorted([f for f in os.listdir(input_directory) if f.endswith('.txt')])

# Iterating over each sorted file in the directory
for filename in files:
    # Extracting 'Dimension' and 'Pole' from the filename
    parts = filename.split('_')
    dimension = dimension_mapping.get(parts[1], parts[1])
    pole = pole_mapping.get(parts[2], parts[2])

    # Opening and reading the file
    with open(os.path.join(input_directory, filename), 'r', encoding='utf-8') as file:
        content = file.read()
        # Find all Text IDs in the file
        text_ids = text_id_pattern.findall(content)
    
    # Construct the dictionary key
    key = f"{dimension} - {pole}"
    
    if key not in dimension_examples:
        dimension_examples[key] = {
            'Dimension': dimension,
            'Pole': pole,
            'Label': f"{key} - Label: <Placeholder for Label>",  # Placeholder for the Label
            'Description': f"{key} - Description: <Placeholder for Description>",  # Placeholder for the Description
            'Text IDs': []
        }

    # Append the Text IDs to the list in the dictionary
    dimension_examples[key]['Text IDs'].extend(text_ids)

# %%
type(dimension_examples)
# Out:
# dict

# %% [markdown]
# ### Exporting to a file

# %%
# Writing the dictionary with string keys to a JSON file
with open(f"{output_directory}/dimension_examples_template.json", 'w') as json_file:
    json.dump(dimension_examples, json_file, indent=4)

# %% [markdown]
# ### Compiling the final `dimension_examples.json` dictionary

# %% [markdown]
# - Copy `dimension_examples_template.json` as `dimension_examples.json`;
# - Complete `dimension_examples.json` with the dimension poles labels and descriptions.

# %% [markdown]
# ## Creating DataFrames according to the definitions in the `dimension_examples.json` dictionary

# %% [markdown]
# ### Loading the `dimension_examples.json` dictionary

# %%
with open(f"{output_directory}/dimension_examples.json", 'r') as json_file:
    dimension_examples = json.load(json_file)

# %% [markdown]
# ### Importing the enriched Target Corpus into a DataFrame

# %%
df_enriched_tc = pd.read_json(f"{input_directory_anova}/debates_turns_parties_scores.jsonl", lines=True)

# %%
df_enriched_tc['Date'] = pd.to_datetime(df_enriched_tc['Date'], unit='ms')

# %%
df_enriched_tc
# Out:
#          File                                 Title  \
# 0     t000000  September 29, 2020 Debate Transcript
# 1     t000001  September 29, 2020 Debate Transcript
# 2     t000002  September 29, 2020 Debate Transcript
# 3     t000003  September 29, 2020 Debate Transcript
# 4     t000004  September 29, 2020 Debate Transcript
# ...       ...                                   ...
# 3423  t003473    October 21, 1960 Debate Transcript
# 3424  t003474    October 21, 1960 Debate Transcript
# 3425  t003475    October 21, 1960 Debate Transcript
# 3426  t003476    October 21, 1960 Debate Transcript
# 3427  t003477    October 21, 1960 Debate Transcript
#
#                                                  Debate       Date  Decade  \
# 0     Presidential Debate at Case Western Reserve Un... 2020-09-29    2020
# 1     Presidential Debate at Case Western Reserve Un... 2020-09-29    2020
# 2     Presidential Debate at Case Western Reserve Un... 2020-09-29    2020
# 3     Presidential Debate at Case Western Reserve Un... 2020-09-29    2020
# 4     Presidential Debate at Case Western Reserve Un... 2020-09-29    2020
# ...                                                 ...        ...     ...
# 3423       The Fourth Kennedy-Nixon Presidential Debate 1960-10-21    1960
# 3424       The Fourth Kennedy-Nixon Presidential Debate 1960-10-21    1960
# 3425       The Fourth Kennedy-Nixon Presidential Debate 1960-10-21    1960
# 3426       The Fourth Kennedy-Nixon Presidential Debate 1960-10-21    1960
# 3427       The Fourth Kennedy-Nixon Presidential Debate 1960-10-21    1960
#
#            Election                                       Participants  \
# 0     2020 Election  Former Vice President Joe Biden (D) and Presid...
# 1     2020 Election  Former Vice President Joe Biden (D) and Presid...
# 2     2020 Election  Former Vice President Joe Biden (D) and Presid...
# 3     2020 Election  Former Vice President Joe Biden (D) and Presid...
# 4     2020 Election  Former Vice President Joe Biden (D) and Presid...
# ...             ...                                                ...
# 3423  1960 Election                                      Kennedy-Nixon
# 3424  1960 Election                                      Kennedy-Nixon
# 3425  1960 Election                                      Kennedy-Nixon
# 3426  1960 Election                                      Kennedy-Nixon
# 3427  1960 Election                                      Kennedy-Nixon
#
#                     Moderators      Speaker       Party  Factor 1  Factor 2  \
# 0     Chris Wallace (Fox News)        TRUMP  Republican         1         8
# 1     Chris Wallace (Fox News)        BIDEN  Democratic         0         1
# 2     Chris Wallace (Fox News)        BIDEN  Democratic        11        11
# 3     Chris Wallace (Fox News)        TRUMP  Republican         1         3
# 4     Chris Wallace (Fox News)        TRUMP  Republican         4         2
# ...                        ...          ...         ...       ...       ...
# 3423               QUINCY HOWE    MR. NIXON  Republican        -7        25
# 3424               QUINCY HOWE  MR. KENNEDY  Democratic         0        25
# 3425               QUINCY HOWE  MR. KENNEDY  Democratic         0         0
# 3426               QUINCY HOWE  MR. KENNEDY  Democratic        12        72
# 3427               QUINCY HOWE    MR. NIXON  Republican         5        50
#
#       Factor 3  Factor 4  Factor 5  Factor 6  \
# 0            0         3         0         3
# 1            0         0         0         0
# 2           -1         5        -7         0
# 3            0         0        -2         0
# 4            0         0        -1         0
# ...        ...       ...       ...       ...
# 3423        -3       -14        -3         0
# 3424         2       -15         0         0
# 3425         0        -1         0         0
# 3426        -4        -7         1        -1
# 3427         1         1        -2         3
#
#                                                    Text
# 0     Thank you very much, Chris. I will tell you ve...
# 1     Well, first of all, thank you for doing this a...
# 2     The American people have a right to have a say...
# 3     There aren’t a hundred million people with pre...
# 4     During that period of time, during that period...
# ...                                                 ...
# 3423  I would say that the issue will stay with us a...
# 3424  Well, Mr. Nixon, to go back to 1955. The resol...
# 3425  And that’s the testimony of uh – General Twini...
# 3426  I uh – said that I’ve served this country for ...
# 3427  Senator Kennedy has said tonight again what he...
#
# [3428 rows x 17 columns]

# %% [markdown]
# ### Creating a DataFrame for each dictionary entry

# %% [markdown]
# - The `df_filtered` DataFrame is explicitly copied using `.copy()` to avoid any `SettingWithCopyWarning`;
# - When setting `Text ID Order`, `.loc` is used to ensure the assignment is made directly on the DataFrame.

# %%
for key, value in dimension_examples.items():
    # Filtering the 'df_enriched_tc' DataFrame to only include rows with 'Text ID's from the dictionary entry
    matching_text_ids = value['Text IDs']
    df_filtered = df_enriched_tc[df_enriched_tc['File'].isin(matching_text_ids)].copy()
    
    # Ensuring the order matches the order in the dictionary
    df_filtered.loc[:, 'Text ID Order'] = pd.Categorical(df_filtered['File'], categories=matching_text_ids, ordered=True)
    df_filtered = df_filtered.sort_values('Text ID Order').drop('Text ID Order', axis=1)

    # Adding additional columns as needed
    df_filtered['Dimension'] = value['Dimension']
    df_filtered['Pole'] = value['Pole']
    df_filtered['Label'] = value['Label']
    df_filtered['Description'] = value['Description']
    
    # Exporting the DataFrame into a JSONL document
    df_filtered[['File', 'Title', 'Debate', 'Date', 'Decade', 'Election', 'Participants', 'Moderators', 'Speaker', 'Party', 'Factor 1', 'Factor 2', 'Factor 3', 'Factor 4', 'Factor 5', 'Factor 6', 'Dimension', 'Pole', 'Label', 'Description', 'Text']].to_json(f"{output_directory}/{key}.jsonl", orient='records', lines=True)

# %% [markdown]
# #### Importing the DataFrames

# %%
df_dim1_neg = pd.read_json(f"{output_directory}/Dimension 1 - Negative Pole.jsonl", lines=True)
df_dim1_neg['Date'] = pd.to_datetime(df_dim1_neg['Date'], unit='ms')

# %%
df_dim1_pos = pd.read_json(f"{output_directory}/Dimension 1 - Positive Pole.jsonl", lines=True)
df_dim1_pos['Date'] = pd.to_datetime(df_dim1_pos['Date'], unit='ms')

# %%
df_dim2_neg = pd.read_json(f"{output_directory}/Dimension 2 - Negative Pole.jsonl", lines=True)
df_dim2_neg['Date'] = pd.to_datetime(df_dim2_neg['Date'], unit='ms')

# %%
df_dim2_pos = pd.read_json(f"{output_directory}/Dimension 2 - Positive Pole.jsonl", lines=True)
df_dim2_pos['Date'] = pd.to_datetime(df_dim2_pos['Date'], unit='ms')

# %%
df_dim3_neg = pd.read_json(f"{output_directory}/Dimension 3 - Negative Pole.jsonl", lines=True)
df_dim3_neg['Date'] = pd.to_datetime(df_dim3_neg['Date'], unit='ms')

# %%
df_dim3_pos = pd.read_json(f"{output_directory}/Dimension 3 - Positive Pole.jsonl", lines=True)
df_dim3_pos['Date'] = pd.to_datetime(df_dim3_pos['Date'], unit='ms')

# %%
df_dim4_neg = pd.read_json(f"{output_directory}/Dimension 4 - Negative Pole.jsonl", lines=True)
df_dim4_neg['Date'] = pd.to_datetime(df_dim4_neg['Date'], unit='ms')

# %%
df_dim4_pos = pd.read_json(f"{output_directory}/Dimension 4 - Positive Pole.jsonl", lines=True)
df_dim4_pos['Date'] = pd.to_datetime(df_dim4_pos['Date'], unit='ms')

# %%
df_dim5_neg = pd.read_json(f"{output_directory}/Dimension 5 - Negative Pole.jsonl", lines=True)
df_dim5_neg['Date'] = pd.to_datetime(df_dim5_neg['Date'], unit='ms')

# %%
df_dim5_pos = pd.read_json(f"{output_directory}/Dimension 5 - Positive Pole.jsonl", lines=True)
df_dim5_pos['Date'] = pd.to_datetime(df_dim5_pos['Date'], unit='ms')

# %%
df_dim6_neg = pd.read_json(f"{output_directory}/Dimension 6 - Negative Pole.jsonl", lines=True)
df_dim6_neg['Date'] = pd.to_datetime(df_dim6_neg['Date'], unit='ms')

# %%
df_dim6_pos = pd.read_json(f"{output_directory}/Dimension 6 - Positive Pole.jsonl", lines=True)
df_dim6_pos['Date'] = pd.to_datetime(df_dim6_pos['Date'], unit='ms')

# %% [markdown]
# ##### Inspecting the DataFrames

# %%
df_dim1_neg
#df_dim1_pos
#df_dim2_neg
#df_dim2_pos
#df_dim3_neg
#df_dim3_pos
#df_dim4_neg
#df_dim4_pos
#df_dim5_neg
#df_dim5_pos
#df_dim6_neg
#df_dim6_pos
# Out:
#        File                                              Title  \
# 0   t002677                 October 13, 1992 Debate Transcript
# 1   t003122                 October 11, 1984 Debate Transcript
# 2   t002120                  October 5, 2000 Debate Transcript
# 3   t002043                         October 3, 2000 Transcript
# 4   t003120                 October 11, 1984 Debate Transcript
# 5   t003473                 October 21, 1960 Debate Transcript
# 6   t003079                  October 7, 1984 Debate Transcript
# 7   t003446                 October 13, 1960 Debate Transcript
# 8   t000901                  October 9, 2016 Debate Transcript
# 9   t003373                 October 22, 1976 Debate Transcript
# 10  t000364  Presidential Debate at Belmont University in N...
# 11  t000380  Presidential Debate at Belmont University in N...
# 12  t001597                  October 2, 2008 Debate Transcript
# 13  t000834                  October 4, 2016 Debate Transcript
# 14  t001305                 October 11, 2012 Debate Transcript
# 15  t001545               September 26, 2008 Debate Transcript
# 16  t001743                 October 15, 2008 Debate Transcript
# 17  t001870                  October 8, 2004 Debate Transcript
# 18  t001991               September 30. 2004 Debate Transcript
# 19  t003022                 October 13, 1988 Debate Transcript
# 20  t003071                  October 7, 1984 Debate Transcript
# 21  t003123                 October 11, 1984 Debate Transcript
# 22  t003225               September 21, 1980 Debate Transcript
# 23  t000330  October 07, 2020 Vice Presidential Debate Tran...
# 24  t000580               September 26, 2016 Debate Transcript
# 25  t000740                  October 4, 2016 Debate Transcript
# 47  Or instead of you violating the Constitution b...
# 48  We have different views on — on refugee issues...
# 49  And with respect to refugees, we want to keep ...
#
# [50 rows x 21 columns]

# %%
df_dim1_neg.at[0, 'Text']
# Out:
# 'This issue is an issue that divides Americans deeply. I happen to be pro-life. I have been pro-life for my 16 years — — in public life. My objective and the president’s objective is to try to reduce abortions in this country. We have 1.6 million abortions. We have more abortions in Washington, DC, than we do live births. Why shouldn’t we have more reflection upon the issue before abor — the decision of abortion is made. I would hope that we would agree upon that. Something like a 24-hour waiting period, parental notification. I was in Los Angeles recently and I talked to a woman who told me that she had an abortion when she was 17 years of age. And looking back on that she said it was a mistake. She said — she said I wished at that time, that I was going through this difficult time, that I had counseling to talk about the post-abortion trauma, and talk about adoption rather than abortion. Because if I had had that discussion, I would have had the child. Let’s not forget that every abortion stops a beating heart. I think we have far too many abortions in this country, in this country of ours.'

# %%
df_dim1_neg.at[0, 'Label']
# Out:
# 'Dimension 1 - Negative Pole - Label: Discourse of Religious Nationalism with Constitutional Conservatism and Ethical Pluralism'

# %%
df_dim1_neg.at[0, 'Description']
# Out:
# 'Dimension 1 - Negative Pole - Description: This discourse integrates a sense of national and religious identity with a commitment to constitutional traditions and ethical diversity. It promotes a vision of governance that aligns religious values with a strong sense of national unity, advocating for policies that safeguard constitutional rights while fostering moral integrity in public life. Emphasizing the ethical underpinnings of laws and policies, it seeks to balance a respect for religious morality with constitutional freedoms, envisioning a pluralistic society rooted in shared moral principles and patriotic commitment.'

# %% [markdown]
# ## Processing the texts with ChatGPT

# %% [markdown]
# ### Defining input variables

# %%
chatgpt_prompt = 'Help me make a text by drawing on the dimension below. The dimension captures the ideology underlying political debates broadcast on TV between presidential candidates. Give me a text that refers to the **LACK** of this ideology. Use the texts below as a source of information for your text, and craft your text in a way that **CONTRADICTS** the texts attached. **PAY ATTENTION TO THE TEXTS AND REPLY USING THE OPPOSITE IDEOLOGY AND DISCOURSES**. Do not mention these texts in your reply. Write your answer in the register (text variety, genre) of a television political debate, with you as one of the presidential candidates.'

# %%
data_set = 'Dimension 1 - Negative Pole'

# %%
df = pd.read_json(f"{output_directory}/{data_set}.jsonl", lines=True)
df['Date'] = pd.to_datetime(df['Date'], unit='ms')

# %% [markdown]
# ### Querying ChatGPT

# %%
# Setting up logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler(f"{output_directory}/chatgpt_processing.log"),
        logging.StreamHandler()
    ]
)

# Loading all environment variables from `.env` into `os.environ`
load_dotenv()

# Importing the required programme variables from the environment
openai.api_key = os.environ.get('OPENAI_API_KEY', '')
assert openai.api_key

# Defining a function to query ChatGPT with exponential backoff
def get_completion(prompt, model='gpt-4o', max_retries=5):
    client = openai.OpenAI()
    messages = [{'role': 'user', 'content': prompt}]
    for attempt in range(max_retries):
        try:
            response = client.chat.completions.create(
                model=model,
                messages=messages,
                temperature=0
            )
            return response.choices[0].message.content
        except openai.error.RateLimitError as e:
            wait_time = 2 ** attempt  # Exponential backoff
            logging.warning(f"Rate limit exceeded. Retrying in {wait_time} seconds...")
            time.sleep(wait_time)
        except Exception as e:
            logging.error(f"Error querying ChatGPT: {e}")
            return None
    logging.error("Max retries exceeded.")
    return None

# Defining a function to process text using ChatGPT
def process_text(text, prompt_template):
    paragraphs = text.split('\n')  # Split text into paragraphs
    processed_paragraphs = []
    for paragraph in paragraphs:
        prompt = prompt_template + paragraph
        try:
            processed_paragraph = get_completion(prompt)
            if processed_paragraph:
                processed_paragraphs.append(processed_paragraph)
            else:
                processed_paragraphs.append(paragraph)  # Keep original if there's an error
        except Exception as e:
            print(f"Error processing paragraph: {e}")
            processed_paragraphs.append(paragraph)  # Keep original if there's an error
    return '\n'.join(processed_paragraphs)

# Applying the function to the 'Text' column with progress indication
processed_texts = []
for index, row in tqdm(df.iterrows(), total=len(df), desc='Processing texts'):
    # Defining the ChatGPT prompt template
    prompt_template = chatgpt_prompt + '\n' + row['Label'] + '\n' + row['Description'] + '\n'
    
    # Processing text
    processed_texts.append(process_text(row['Text'], prompt_template))

df['Text ChatGPT'] = processed_texts
# Out:
# Processing texts:   0%|          | 0/50 [00:00<?, ?it/s]2024-11-12 16:04:09,355 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:   2%|▏         | 1/50 [00:09<07:35,  9.30s/it]2024-11-12 16:04:27,250 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:   4%|▍         | 2/50 [00:27<11:28, 14.35s/it]2024-11-12 16:04:35,208 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:   6%|▌         | 3/50 [00:35<08:57, 11.43s/it]2024-11-12 16:04:44,526 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:   8%|▊         | 4/50 [00:44<08:07, 10.60s/it]2024-11-12 16:04:53,351 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  10%|█         | 5/50 [00:53<07:28,  9.96s/it]2024-11-12 16:05:00,367 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  12%|█▏        | 6/50 [01:00<06:34,  8.96s/it]2024-11-12 16:05:08,614 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  14%|█▍        | 7/50 [01:08<06:15,  8.73s/it]2024-11-12 16:05:16,621 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  16%|█▌        | 8/50 [01:16<05:56,  8.50s/it]2024-11-12 16:05:27,091 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  18%|█▊        | 9/50 [01:27<06:13,  9.11s/it]2024-11-12 16:05:39,144 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  20%|██        | 10/50 [01:39<06:40, 10.02s/it]2024-11-12 16:05:46,710 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  22%|██▏       | 11/50 [01:46<06:01,  9.27s/it]2024-11-12 16:05:53,419 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  24%|██▍       | 12/50 [01:53<05:22,  8.49s/it]2024-11-12 16:06:03,744 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  26%|██▌       | 13/50 [02:03<05:34,  9.05s/it]2024-11-12 16:06:13,928 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  28%|██▊       | 14/50 [02:13<05:38,  9.39s/it]2024-11-12 16:06:24,997 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  30%|███       | 15/50 [02:24<05:46,  9.90s/it]2024-11-12 16:06:35,966 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  32%|███▏      | 16/50 [02:35<05:47, 10.22s/it]2024-11-12 16:06:43,101 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  34%|███▍      | 17/50 [02:43<05:06,  9.29s/it]2024-11-12 16:06:50,005 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  36%|███▌      | 18/50 [02:49<04:34,  8.57s/it]2024-11-12 16:07:01,414 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  38%|███▊      | 19/50 [03:01<04:52,  9.43s/it]2024-11-12 16:07:09,465 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  40%|████      | 20/50 [03:09<04:30,  9.01s/it]2024-11-12 16:07:17,712 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  42%|████▏     | 21/50 [03:17<04:14,  8.78s/it]2024-11-12 16:07:24,875 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  44%|████▍     | 22/50 [03:24<03:52,  8.30s/it]2024-11-12 16:07:36,006 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  46%|████▌     | 23/50 [03:35<04:06,  9.15s/it]2024-11-12 16:07:41,896 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  48%|████▊     | 24/50 [03:41<03:32,  8.17s/it]2024-11-12 16:07:51,534 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  50%|█████     | 25/50 [03:51<03:35,  8.61s/it]2024-11-12 16:07:58,995 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  52%|█████▏    | 26/50 [03:58<03:18,  8.27s/it]2024-11-12 16:08:08,268 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  54%|█████▍    | 27/50 [04:08<03:17,  8.57s/it]2024-11-12 16:08:15,942 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  56%|█████▌    | 28/50 [04:15<03:02,  8.30s/it]2024-11-12 16:08:24,298 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  58%|█████▊    | 29/50 [04:24<02:54,  8.32s/it]2024-11-12 16:08:31,558 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  60%|██████    | 30/50 [04:31<02:39,  8.00s/it]2024-11-12 16:08:38,209 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  62%|██████▏   | 31/50 [04:38<02:24,  7.59s/it]2024-11-12 16:08:44,892 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  64%|██████▍   | 32/50 [04:44<02:11,  7.33s/it]2024-11-12 16:08:54,059 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  66%|██████▌   | 33/50 [04:53<02:13,  7.87s/it]2024-11-12 16:09:03,241 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  68%|██████▊   | 34/50 [05:03<02:12,  8.27s/it]2024-11-12 16:09:11,478 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  70%|███████   | 35/50 [05:11<02:03,  8.26s/it]2024-11-12 16:09:18,570 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  72%|███████▏  | 36/50 [05:18<01:50,  7.91s/it]2024-11-12 16:09:28,468 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  74%|███████▍  | 37/50 [05:28<01:50,  8.50s/it]2024-11-12 16:09:35,373 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  76%|███████▌  | 38/50 [05:35<01:36,  8.03s/it]2024-11-12 16:09:43,527 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  78%|███████▊  | 39/50 [05:43<01:28,  8.06s/it]2024-11-12 16:09:50,462 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  80%|████████  | 40/50 [05:50<01:17,  7.73s/it]2024-11-12 16:09:58,327 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  82%|████████▏ | 41/50 [05:58<01:09,  7.77s/it]2024-11-12 16:10:05,867 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  84%|████████▍ | 42/50 [06:05<01:01,  7.70s/it]2024-11-12 16:10:12,812 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  86%|████████▌ | 43/50 [06:12<00:52,  7.47s/it]2024-11-12 16:10:22,162 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  88%|████████▊ | 44/50 [06:22<00:48,  8.04s/it]2024-11-12 16:10:32,503 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  90%|█████████ | 45/50 [06:32<00:43,  8.73s/it]2024-11-12 16:10:40,077 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  92%|█████████▏| 46/50 [06:40<00:33,  8.38s/it]2024-11-12 16:10:49,857 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  94%|█████████▍| 47/50 [06:49<00:26,  8.80s/it]2024-11-12 16:11:01,872 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  96%|█████████▌| 48/50 [07:01<00:19,  9.77s/it]2024-11-12 16:11:14,746 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  98%|█████████▊| 49/50 [07:14<00:10, 10.70s/it]2024-11-12 16:11:22,021 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts: 100%|██████████| 50/50 [07:21<00:00,  8.84s/it]

# %% [markdown]
# #### Exporting to a file

# %%
df.to_json(f"{output_directory}/{data_set}-ChatGPT.jsonl", orient='records', lines=True)

# %% [markdown]
# #### Exporting each text processed by ChatGPT to individual files for inspection

# %%
for index, row in df.iterrows():
    # Constructing the file name based on row data and index
    file_name = f"{output_directory}/{row['Dimension']}_{row['Pole']}_{index}_{row['File']}_chatgpt.txt"
    
    # Writing the 'Text ChatGPT' content to the file
    with open(file_name, 'w', encoding='utf-8') as file:
        file.write(row['Text ChatGPT'])
