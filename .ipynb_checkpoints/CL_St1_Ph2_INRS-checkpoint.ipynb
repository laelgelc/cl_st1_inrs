# %% [markdown]
# <center>
# <img src="https://laelgelcpublic.s3.sa-east-1.amazonaws.com/lael_50_years_narrow_white.png.no_years.400px_96dpi.png" width="300" alt="LAEL 50 years logo">
# <h3>APPLIED LINGUISTICS GRADUATE PROGRAMME (LAEL)</h3>
# </center>
# <hr>

# %% [markdown]
# # Corpus Linguistics - Study 1 - Phase 2 - INRS

# %% [markdown]
# # [US Presidential and Vice Presidential debates](https://www.debates.org/voter-education/debate-transcripts/) target _corpus_ definition

# %% [markdown]
# This solution prepares the target _corpus_ for Lexical Multidimensional Analysis
# - **Definition of text**: In this study, a text is defined as a turn of a candidate longer or equal to 10 words. Therefore, the speeches of the moderators and members of the audience should not be considered

# %% [markdown]
# ## Required Python packages

# %% [markdown]
# - pandas

# %% [markdown]
# ## Importing the required libraries

# %%
import re
import pandas as pd
import os
import sys

# %% [markdown]
# ### Defining input variables

# %%
# List of debates
debate_1 = 'September 29, 2020 Debate Transcript'

debate_2 = 'October 07, 2020 Vice Presidential Debate Transcript'

debate_3 = 'October 22, 2020 Debate Transcript'

debate_4 = 'September 26, 2016 Debate Transcript'

debate_5 = 'October 4, 2016 Debate Transcript'

debate_6 = 'October 9, 2016 Debate Transcript'

debate_7 = 'October 19, 2016 Debate Transcript'

debate_8 = 'October 3, 2012 Debate Transcript'

debate_9 = 'October 11, 2012 Debate Transcript'

debate_10 = 'October 16, 2012 Debate Transcript'

debate_11 = 'October 22, 2012 Debate Transcript'

debate_12 = 'September 26, 2008 Debate Transcript'

debate_13 = 'October 2, 2008 Debate Transcript'

debate_14 = 'October 7, 2008 Debate Transcript'

debate_15 = 'October 15, 2008 Debate Transcript'

debate_16 = 'October 13, 2004 Debate Transcript'

debate_17 = 'October 8, 2004 Debate Transcript'

debate_18 = 'October 5, 2004 Transcript'

debate_19 = 'September 30, 2004 Debate Transcript'

debate_20 = 'October 3, 2000 Transcript'

debate_21 = 'October 5, 2000 Debate Transcript'

debate_22 = 'October 11, 2000 Debate Transcript'

debate_23 = 'October 17, 2000 Debate Transcript'

debate_24 = 'October 6, 1996 Debate Transcript'

debate_25 = 'October 9, 1996 Debate Transcript'

debate_26 = 'October 16, 1996 Debate Transcript'

debate_27 = 'October 11, 1992 First Half Debate Transcript'

debate_28 = 'October 11, 1992 Second Half Debate Transcript'

debate_29 = 'October 13, 1992 Debate Transcript'

debate_30 = 'October 15, 1992 First Half Debate Transcript'

debate_31 = 'October 15, 1992 Second Half Debate Transcript'

debate_32 = 'October 19, 1992 Debate Transcript'

debate_33 = 'September 25, 1988 Debate Transcript'

debate_34 = 'October 5, 1988 Debate Transcripts'

debate_35 = 'October 13, 1988 Debate Transcript'

debate_36 = 'October 7, 1984 Debate Transcript'

debate_37 = 'October 11, 1984 Debate Transcript'

debate_38 = 'October 21, 1984 Debate Transcript'

debate_39 = 'September 21, 1980 Debate Transcript'

debate_40 = 'October 28, 1980 Debate Transcript'

debate_41 = 'September 23, 1976 Debate Transcript'

debate_42 = 'October 6, 1976 Debate Transcript'

debate_43 = 'October 22, 1976 Debate Transcript'

debate_44 = 'September 26, 1960 Debate Transcript'

debate_45 = 'October 7, 1960 Debate Transcript'

debate_46 = 'October 13, 1960 Debate Transcript'

debate_47 = 'October 21, 1960 Debate Transcript'

debates_list = [
    debate_1, 
    debate_2, 
    debate_3, 
    debate_4, 
    debate_5, 
    debate_6, 
    debate_7, 
    debate_8, 
    debate_9, 
    debate_10, 
    debate_11, 
    debate_12, 
    debate_13, 
    debate_14, 
    debate_15, 
    debate_16, 
    debate_17, 
    debate_18, 
    debate_19, 
    debate_20, 
    debate_21, 
    debate_22, 
    debate_23, 
    debate_24, 
    debate_25, 
    debate_26, 
    debate_27, 
    debate_28, 
    debate_29, 
    debate_30, 
    debate_31, 
    debate_32, 
    debate_33, 
    debate_34, 
    debate_35, 
    debate_36, 
    debate_37, 
    debate_38, 
    debate_39, 
    debate_40, 
    debate_41, 
    debate_42, 
    debate_43, 
    debate_44, 
    debate_45, 
    debate_46, 
    debate_47
]

input_directory = 'cl_st1_inrs'

output_directory = 'cl_st1_inrs_tc'

# %% [markdown]
# ### Creating output directory

# %%
# Check if the output directory already exists. If it does, do nothing. If it doesn't exist, create it.
if os.path.exists(output_directory):
    print('Output directory already exists.')
else:
    try:
        os.makedirs(output_directory)
        print('Output directory successfully created.')
    except OSError as e:
        print('Failed to create the directory:', e)
        sys.exit(1)
# Out:
# Output directory successfully created.

# %% [markdown]
# ## Importing the debates into a single DataFrame

# %%
# Initialising the DataFrame of debates
df_debates = pd.DataFrame()

# Concatenating the various DataFrames into a single DataFrame of debates
for debate in debates_list:
    debate_filename = f'{input_directory}/{debate}.jsonl'
    df = pd.read_json(debate_filename, lines=True)
    df_debates = pd.concat([df_debates, df], ignore_index=True)

# %%
df_debates.dtypes
# Out:
# Title                   object
# Debate                  object
# Date            datetime64[ns]
# Participants            object
# Moderators              object
# Speaker                 object
# Text                    object
# dtype: object

# %%
df_debates
# Out:
#                                       Title  \
# 0      September 29, 2020 Debate Transcript
# 1      September 29, 2020 Debate Transcript
# 2      September 29, 2020 Debate Transcript
# 3      September 29, 2020 Debate Transcript
# 4      September 29, 2020 Debate Transcript
# ...                                     ...
# 14516    October 21, 1960 Debate Transcript
# 14517    October 21, 1960 Debate Transcript
# 14518    October 21, 1960 Debate Transcript
# 14519    October 21, 1960 Debate Transcript
# 14520    October 21, 1960 Debate Transcript
#
#                                                   Debate       Date  \
# 0      Presidential Debate at Case Western Reserve Un... 2020-09-29
# 1      Presidential Debate at Case Western Reserve Un... 2020-09-29
# 2      Presidential Debate at Case Western Reserve Un... 2020-09-29
# 3      Presidential Debate at Case Western Reserve Un... 2020-09-29
# 4      Presidential Debate at Case Western Reserve Un... 2020-09-29
# ...                                                  ...        ...
# 14516       The Fourth Kennedy-Nixon Presidential Debate 1960-10-21
# 14517       The Fourth Kennedy-Nixon Presidential Debate 1960-10-21
# 14518       The Fourth Kennedy-Nixon Presidential Debate 1960-10-21
# 14519       The Fourth Kennedy-Nixon Presidential Debate 1960-10-21
# 14520       The Fourth Kennedy-Nixon Presidential Debate 1960-10-21
#
#                                             Participants  \
# 0      Former Vice President Joe Biden (D) and Presid...
# 1      Former Vice President Joe Biden (D) and Presid...
# 2      Former Vice President Joe Biden (D) and Presid...
# 3      Former Vice President Joe Biden (D) and Presid...
# 4      Former Vice President Joe Biden (D) and Presid...
# ...                                                  ...
# 14516                                      Kennedy-Nixon
# 14517                                      Kennedy-Nixon
# 14518                                      Kennedy-Nixon
# 14519                                      Kennedy-Nixon
# 14520                                      Kennedy-Nixon
#
#                      Moderators      Speaker  \
# 0      Chris Wallace (Fox News)      WALLACE
# 1      Chris Wallace (Fox News)      WALLACE
# 2      Chris Wallace (Fox News)        BIDEN
# 3      Chris Wallace (Fox News)        TRUMP
# 4      Chris Wallace (Fox News)        BIDEN
# ...                         ...          ...
# 14516               QUINCY HOWE     MR. HOWE
# 14517               QUINCY HOWE  MR. KENNEDY
# 14518               QUINCY HOWE     MR. HOWE
# 14519               QUINCY HOWE    MR. NIXON
# 14520               QUINCY HOWE     MR. HOWE
#
#                                                     Text
# 0      Good evening from the Health Education Campus ...
# 1      This debate is being conducted under health an...
# 2                                    How you doing, man?
# 3                                     How are you doing?
# 4                                              I’m well.
# ...                                                  ...
# 14516  Under the agreed rules, gentlemen, we’ve exhau...
# 14517  I uh – said that I’ve served this country for ...
# 14518  Now, Vice President Nixon, your closing statem...
# 14519  Senator Kennedy has said tonight again what he...
# 14520  Thank you gentlemen. Both candidates have aske...
#
# [14521 rows x 7 columns]

# %%
df_debates.columns
# Out:
# Index(['Title', 'Debate', 'Date', 'Participants', 'Moderators', 'Speaker',
#        'Text'],
#       dtype='object')

# %% [markdown]
# ## Inspecting the words in the `Text` column for expressions that should be filtered out

# %%
# Combining all text data in the column 'Text' into a single string
all_text = ' '.join(df_debates['Text'])

# Splitting the combined text into individual words and converting to lower case
words = all_text.lower().split()

# Removing punctuation and other non-alphabetic characters (in this case, considered not necessary)
#words = [re.sub(r'\W+', '', word) for word in words]

# Converting the list of words into a set to get unique words
unique_words = set(words)

# Convert the set back to a sorted list (optional)
unique_words = sorted(unique_words)

with open(f'{output_directory}/unique_words.txt', 'w', encoding='utf8', newline='\n') as file:
    for word in unique_words:
        file.write(f'{word}\n')

# %% [markdown]
# ### Removing selected patterns (through inspecting `unique_words.txt`)

# %%
# List of patterns to remove
patterns_to_remove = [
    r'\[applause\]',
    r'\[cross talk\]',
    r'\[crosstalk\]',
    r'\[laughing\]',
    r'\[Laughter and applause\]',
    r'\[laughter\.\]',
    r'\[laughter\]',
    r'\[sic\]',
    r'\[to Biden\]',
    r'\[twenty-seven-minute delay\]',
    r'\[unintelligible\]'
]

# Defining a function to remove specific patterns
def remove_specific_patterns(input_line):
    for pattern in patterns_to_remove:
        input_line = re.sub(pattern, '', input_line, flags=re.IGNORECASE) # This flag makes the filtering independent of case
    return input_line

# Removing specific patterns from the 'Text' column
df_debates['Text'] = df_debates['Text'].apply(remove_specific_patterns)

# %% [markdown]
# ## Grouping paragraphs into turns

# %%
# Defining a function to concatenate rows to DataFrames
def concat_row(row, df):
      # Converting the new row to a DataFrame
      row_df = pd.DataFrame([row])

      # Using 'concat' to append the new row
      df = pd.concat([df, row_df], ignore_index=True)

      return df

# Initializing the DataFrame of turns of debate with padding data
df_debates_turns = pd.DataFrame(columns=df_debates.columns)
padding_row = {
    'Title': 'title',
    'Debate': 'debate',
    'Date': '2024-07-18',
    'Participants': 'participants',
    'Moderators': 'moderators',
    'Speaker': 'speaker',
    'Text': 'text'
}

# Concatenating the row to the DataFrame of turns of debate
df_debates_turns = concat_row(padding_row, df_debates_turns)
df_debates_turns['Date'] = df_debates_turns['Date'].astype('datetime64[ns]') # Explicitly setting the column 'Date' to the right data type

# Initializing variables to track consecutive speakers and their texts
current_speaker = None
current_text = ''

# Iterating through rows of the DataFrame of debates
for index, row in df_debates.iterrows():
    # Capturing the columns into variables for streamlined handling
    title = row['Title']
    debate = row['Debate']
    date = row['Date']
    participants = row['Participants']
    moderators = row['Moderators']
    speaker =row['Speaker']
    text = row['Text']
    
    # Checking if the speaker remains the same
    if row['Speaker'] == current_speaker:
        current_text += ' ' + text
    else:
        # Adding the row of the previous speaker
        if current_speaker is not None:
            new_row = {
                'Title': title,
                'Debate': debate,
                'Date': date,
                'Participants': participants,
                'Moderators': moderators,
                'Speaker': current_speaker,
                'Text': current_text
            }

            # Concatenating the row to the DataFrame of turns of debate
            df_debates_turns = concat_row(new_row, df_debates_turns)
        # Updating current speaker and text
        current_speaker = speaker
        current_text = text

# Adding the row of the last speaker
new_row = {
    'Title': title,
    'Debate': debate,
    'Date': date,
    'Participants': participants,
    'Moderators': moderators,
    'Speaker': current_speaker,
    'Text': current_text
}

# Concatenating the row to the DataFrame of turns of debate
df_debates_turns = concat_row(new_row, df_debates_turns)

# Dropping the padding row in the DataFrame of turns of debate
df_debates_turns.drop(0, inplace=True)
df_debates_turns = df_debates_turns.reset_index(drop=True)

# %%
df_debates_turns
# Out:
#                                      Title  \
# 0     September 29, 2020 Debate Transcript
# 1     September 29, 2020 Debate Transcript
# 2     September 29, 2020 Debate Transcript
# 3     September 29, 2020 Debate Transcript
# 4     September 29, 2020 Debate Transcript
# ...                                    ...
# 8540    October 21, 1960 Debate Transcript
# 8541    October 21, 1960 Debate Transcript
# 8542    October 21, 1960 Debate Transcript
# 8543    October 21, 1960 Debate Transcript
# 8544    October 21, 1960 Debate Transcript
#
#                                                  Debate       Date  \
# 0     Presidential Debate at Case Western Reserve Un... 2020-09-29
# 1     Presidential Debate at Case Western Reserve Un... 2020-09-29
# 2     Presidential Debate at Case Western Reserve Un... 2020-09-29
# 3     Presidential Debate at Case Western Reserve Un... 2020-09-29
# 4     Presidential Debate at Case Western Reserve Un... 2020-09-29
# ...                                                 ...        ...
# 8540       The Fourth Kennedy-Nixon Presidential Debate 1960-10-21
# 8541       The Fourth Kennedy-Nixon Presidential Debate 1960-10-21
# 8542       The Fourth Kennedy-Nixon Presidential Debate 1960-10-21
# 8543       The Fourth Kennedy-Nixon Presidential Debate 1960-10-21
# 8544       The Fourth Kennedy-Nixon Presidential Debate 1960-10-21
#
#                                            Participants  \
# 0     Former Vice President Joe Biden (D) and Presid...
# 1     Former Vice President Joe Biden (D) and Presid...
# 2     Former Vice President Joe Biden (D) and Presid...
# 3     Former Vice President Joe Biden (D) and Presid...
# 4     Former Vice President Joe Biden (D) and Presid...
# ...                                                 ...
# 8540                                      Kennedy-Nixon
# 8541                                      Kennedy-Nixon
# 8542                                      Kennedy-Nixon
# 8543                                      Kennedy-Nixon
# 8544                                      Kennedy-Nixon
#
#                     Moderators      Speaker  \
# 0     Chris Wallace (Fox News)      WALLACE
# 1     Chris Wallace (Fox News)        BIDEN
# 2     Chris Wallace (Fox News)        TRUMP
# 3     Chris Wallace (Fox News)        BIDEN
# 4     Chris Wallace (Fox News)      WALLACE
# ...                        ...          ...
# 8540               QUINCY HOWE     MR. HOWE
# 8541               QUINCY HOWE  MR. KENNEDY
# 8542               QUINCY HOWE     MR. HOWE
# 8543               QUINCY HOWE    MR. NIXON
# 8544               QUINCY HOWE     MR. HOWE
#
#                                                    Text
# 0     Good evening from the Health Education Campus ...
# 1                                   How you doing, man?
# 2                                    How are you doing?
# 3                                             I’m well.
# 4     Gentlemen, a lot of people have been waiting f...
# ...                                                 ...
# 8540  Under the agreed rules, gentlemen, we’ve exhau...
# 8541  I uh – said that I’ve served this country for ...
# 8542  Now, Vice President Nixon, your closing statem...
# 8543  Senator Kennedy has said tonight again what he...
# 8544  Thank you gentlemen. Both candidates have aske...
#
# [8545 rows x 7 columns]

# %% [markdown]
# ### Inspecting the grouping into turns

# %%
df_debates.at[0, 'Text']
# Out:
# 'Good evening from the Health Education Campus of Case Western Reserve University and the Cleveland Clinic. I’m Chris Wallace of Fox News and I welcome you to the first of the 2020 presidential debates between President Donald J. Trump and former Vice President Joe Biden. This debate is sponsored by the Commission on Presidential Debates. The Commission has designed the format, six roughly 15-minute segments with two-minute answers from each candidate to the first question, then open discussion for the rest of each segment. Both campaigns have agreed to these rules. For the record, I decided the topics and the questions in each topic. I can assure you none of the questions has been shared with the Commission or the two candidates.'

# %%
df_debates.at[1, 'Text']
# Out:
# 'This debate is being conducted under health and safety protocols designed by the Cleveland Clinic, which is serving as the health security advisor to the Commission for all four debates. As a precaution, both campaigns have agreed the candidates will not shake hands at the beginning of tonight’s debate. The audience here in the hall has promised to remain silent. No cheers, no boos, or other interruptions so we, and more importantly you, can focus on what the candidates have to say. No noise except right now, as we welcome the Republican nominee, President Trump, and the Democratic nominee Vice President Biden.'

# %%
df_debates_turns.at[0, 'Text']
# Out:
# 'Good evening from the Health Education Campus of Case Western Reserve University and the Cleveland Clinic. I’m Chris Wallace of Fox News and I welcome you to the first of the 2020 presidential debates between President Donald J. Trump and former Vice President Joe Biden. This debate is sponsored by the Commission on Presidential Debates. The Commission has designed the format, six roughly 15-minute segments with two-minute answers from each candidate to the first question, then open discussion for the rest of each segment. Both campaigns have agreed to these rules. For the record, I decided the topics and the questions in each topic. I can assure you none of the questions has been shared with the Commission or the two candidates. This debate is being conducted under health and safety protocols designed by the Cleveland Clinic, which is serving as the health security advisor to the Commission for all four debates. As a precaution, both campaigns have agreed the candidates will not shake hands at the beginning of tonight’s debate. The audience here in the hall has promised to remain silent. No cheers, no boos, or other interruptions so we, and more importantly you, can focus on what the candidates have to say. No noise except right now, as we welcome the Republican nominee, President Trump, and the Democratic nominee Vice President Biden.'

# %% [markdown]
# ## Removing turns shorter than 10 words (deemed as discursively not relevant)

# %%
df_debates_turns = df_debates_turns[df_debates_turns['Text'].str.split().str.len().ge(10)]
df_debates_turns = df_debates_turns.reset_index(drop=True)

# %%
df_debates_turns
# Out:
#                                      Title  \
# 0     September 29, 2020 Debate Transcript
# 1     September 29, 2020 Debate Transcript
# 2     September 29, 2020 Debate Transcript
# 3     September 29, 2020 Debate Transcript
# 4     September 29, 2020 Debate Transcript
# ...                                    ...
# 5182    October 21, 1960 Debate Transcript
# 5183    October 21, 1960 Debate Transcript
# 5184    October 21, 1960 Debate Transcript
# 5185    October 21, 1960 Debate Transcript
# 5186    October 21, 1960 Debate Transcript
#
#                                                  Debate       Date  \
# 0     Presidential Debate at Case Western Reserve Un... 2020-09-29
# 1     Presidential Debate at Case Western Reserve Un... 2020-09-29
# 2     Presidential Debate at Case Western Reserve Un... 2020-09-29
# 3     Presidential Debate at Case Western Reserve Un... 2020-09-29
# 4     Presidential Debate at Case Western Reserve Un... 2020-09-29
# ...                                                 ...        ...
# 5182       The Fourth Kennedy-Nixon Presidential Debate 1960-10-21
# 5183       The Fourth Kennedy-Nixon Presidential Debate 1960-10-21
# 5184       The Fourth Kennedy-Nixon Presidential Debate 1960-10-21
# 5185       The Fourth Kennedy-Nixon Presidential Debate 1960-10-21
# 5186       The Fourth Kennedy-Nixon Presidential Debate 1960-10-21
#
#                                            Participants  \
# 0     Former Vice President Joe Biden (D) and Presid...
# 1     Former Vice President Joe Biden (D) and Presid...
# 2     Former Vice President Joe Biden (D) and Presid...
# 3     Former Vice President Joe Biden (D) and Presid...
# 4     Former Vice President Joe Biden (D) and Presid...
# ...                                                 ...
# 5182                                      Kennedy-Nixon
# 5183                                      Kennedy-Nixon
# 5184                                      Kennedy-Nixon
# 5185                                      Kennedy-Nixon
# 5186                                      Kennedy-Nixon
#
#                     Moderators      Speaker  \
# 0     Chris Wallace (Fox News)      WALLACE
# 1     Chris Wallace (Fox News)      WALLACE
# 2     Chris Wallace (Fox News)        TRUMP
# 3     Chris Wallace (Fox News)      WALLACE
# 4     Chris Wallace (Fox News)        BIDEN
# ...                        ...          ...
# 5182               QUINCY HOWE  MR. KENNEDY
# 5183               QUINCY HOWE     MR. HOWE
# 5184               QUINCY HOWE  MR. KENNEDY
# 5185               QUINCY HOWE    MR. NIXON
# 5186               QUINCY HOWE     MR. HOWE
#
#                                                    Text
# 0     Good evening from the Health Education Campus ...
# 1     Gentlemen, a lot of people have been waiting f...
# 2     Thank you very much, Chris. I will tell you ve...
# 3     President Trump, thank you. Same question to y...
# 4     Well, first of all, thank you for doing this a...
# ...                                                 ...
# 5182  And that’s the testimony of uh – General Twini...
# 5183  Under the agreed rules, gentlemen, we’ve exhau...
# 5184  I uh – said that I’ve served this country for ...
# 5185  Senator Kennedy has said tonight again what he...
# 5186  Thank you gentlemen. Both candidates have aske...
#
# [5187 rows x 7 columns]

# %% [markdown]
# ## Focusing the target _corpus_ to the speech of the candidates

# %% [markdown]
# ### Determining who are the candidates

# %%
df_debates_turns['Participants'].unique()
# Out:
# array(['Former Vice President Joe Biden (D) and President Donald Trump (R)',
#        'Senator Kamala Harris (D-CA) and Vice President Mike Pence (R)',
#        'Former Secretary of State Hillary Clinton (D) and Businessman Donald Trump (R)',
#        'Senator Tim Kaine (D-VA) and Governor Mike Pence (R-IN)',
#        'FORMER GOV. MITT ROMNEY, R-MASS. PRESIDENT BARACK OBAMA',
#        'VICE PRESIDENT JOSEPH R. BIDEN JR. REP. PAUL D. RYAN, R-WIS.',
#        'FORMER GOV. MITT ROMNEY, R-MASS., PRESIDENT BARACK OBAMA',
#        'U.S. SENATOR JOHN MCCAIN (AZ)REPUBLICAN PRESIDENTIAL NOMINEE U. S. SENATOR BARACK OBAMA (IL)DEMOCRATIC PRESIDENTIAL NOMINEE',
#        'SEN. JOSEPH R. BIDEN JR. (DE) DEMOCRATIC VICE PRESIDENTIAL NOMINEE GOV. SARAH PALIN, (AK) REPUBLICAN VICE PRESIDENTIAL NOMINEE',
#        'GEORGE W. BUSHPRESIDENT OF THE UNITED STATES U. S. SENATOR JOHN F. KERRY (MA)DEMOCRATIC PRESIDENTIAL NOMINEE',
#        'GEORGE W. BUSHPRESIDENT OF THE UNITED STATES U.S. SENATOR JOHN F. KERRY (MA)DEMOCRATIC PRESIDENTIAL NOMINEE',
#        'RICHARD B. CHENEY, VICE PRESIDENT OF THE UNITED STATES U.S. SENATOR JOHN EDWARDS (NC), DEMOCRATIC VICE PRESIDENTIAL NOMINEE',
#        'GEORGE W. BUSH, PRESIDENT OF THE UNITED STATES U.S. SENATOR JOHN F. KERRY (MA), DEMOCRATIC PRESIDENTIAL NOMINEE',
#        'Gore-Bush', 'Lieberman-Cheney', 'Clinton-Dole', 'Gore-Kemp',
#        'Clinton-Bush-Perot', 'Gore-Quayle-Stockdale', 'Bush-Dukakis',
#        'Bentsen-Quayle', 'Reagan-Mondale', 'Bush-Ferraro',
#        'Anderson-Reagan', 'Carter-Reagan', 'Carter-Ford', 'Kennedy-Nixon'],
#       dtype=object)

# %% [markdown]
# ### Determining who are the speakers

# %%
df_debates_turns['Speaker'].unique()
# Out:
# array(['WALLACE', 'TRUMP', 'BIDEN', 'PAGE', 'HARRIS', 'PENCE', 'WELKER',
#        'HOLT', 'CLINTON', 'QUIJANO', 'KAINE', 'COOPER', 'RADDATZ',
#        'QUESTION', 'LEHRER', 'OBAMA', 'ROMNEY', 'RYAN', 'CROWLEY',
#        'SCHIEFFER', 'ROMNEHY', 'MCCAIN', 'IFILL', 'PALIN', 'BROKAW',
#        'KERRY', 'BUSH', 'GIBSON', 'OTIS', 'DAHLE', 'BALDI', 'WASHINGTON',
#        'JACOBS', 'FARLEY', 'BRONSING', 'HORSTMAN', 'LAURENT', 'VARNER',
#        'HUBB', 'BARROW', 'FOWLER', 'LONG', 'MICHAELSON', 'DEGENHART',
#        'GRABEL', 'CHENEY', 'EDWARDS', 'MODERATOR', 'GORE', 'LIEBERMAN',
#        'MEMBER OF AUDIENCE', 'DOLE', 'KEMP', 'MS. McAFEE', 'DR. BERKLEY',
#        'MR. MILLIGAN', 'MS. KELLY', 'MR. DELGADO', 'MR. FLECK',
#        'MS. GONZALEZ', 'MS. JOHNSON', 'MS. NAUDIN', 'MS. SANDERS',
#        'MR. DAVID', 'MR. BURNS', 'MS. GIANNOTTI', 'MR. GOLDFARB',
#        'MS. STRATEGOS', 'MS. SIEFERT', 'MR. SMITH', 'MR. KITE',
#        'MS. DUBE', 'PEROT', 'PRESIDENT BUSH', 'COMPTON', 'SANDER VANOCUR',
#        'MASHEK', 'VANOCUR', 'HAL BRUNO', 'SENATOR GORE',
#        'VICE PRESIDENT QUAYLE', 'BRUNO', 'QUAYLE', 'ADMIRAL STOCKDALE',
#        'STOCKDALE', 'CAROLE SIMPSON', 'AUDIENCE QUESTION', 'ROSS PEROT',
#        'SIMPSON', 'GOVERNOR CLINTON', 'JIM LEHRER', 'ROOK', 'THOMAS',
#        'GIBBONS', 'DUKAKIS', 'GROER', 'JENNINGS', 'WOODRUFF', 'BENTSEN',
#        'MARGOLIS', 'HUME', 'SHAW', 'WARNER', 'MITCHELL', 'MS. RIDINGS',
#        'MS. WALTERS', 'MR. WIEGHART', 'MR. MONDALE', 'THE PRESIDENT',
#        'MS. SAWYER', 'MR. BARNES', 'DOROTHY S. RIDINGS', 'FERRARO',
#        'WHITE', 'QUARLES', 'BOYD', 'MR. NEWMAN', 'MS. GEYER', 'MR. KALB',
#        'MR. KONDRACKE',
#        'RUTH J. HINERFELD, CHAIR, LEAGUE OF WOMEN VOTERS EDUCATION FUND',
#        'CAROL LOOMIS, BOARD OF EDITORS, FORTUNE MAGAZINE',
#        'REP. JOHN B. ANDERSON', 'LOOMIS', 'GOV. RONALD REAGAN',
#        'ANDERSON', 'REAGAN', 'MOYERS', 'GREENBERG, SYNDICATED COLUMNIST',
#        'GREENBERG',
#        'CHARLES CORDDRY, MILITARY CORRESPONDENT, THE SUN, BALTIMORE',
#        'CORDDRY', 'MAY', 'QUINN',
#        'GOLDEN, EDITORIAL WRITER, THE NEW YORK TIMES', 'GOLDEN',
#        'RUTH HINERFELD, LEAGUE OF WOMEN VOTERS, EDUCATION FUND',
#        'MR. SMITH, ABC NEWS', 'MARVIN STONE, U.S. NEWS AND WORLD REPORT',
#        'MR. REAGAN', 'MR. STONE', 'MR. CARTER',
#        'MR. ELLIS, CHRISTIAN SCIENCE MONITOR', 'MR. ELLIS',
#        'WILLIAM HILLIARD, PORTLAND OREGONIAN', 'MR. HILLIARD',
#        'BARBARA WALTERS', 'HARRY ELLIS', 'EDWIN NEWMAN, MODERATOR',
#        'MR. REYNOLDS', 'MR. FORD', 'MR. GANNON', 'MS. DREW',
#        'MS. FREDERICK', 'MR. FRANKEL', 'MR. TREWHITT', 'MR. VALERIANI',
#        'MR. KRAFT', 'MR. MAYNARD', 'MR. NELSON', 'MR.FORD',
#        'HOWARD K. SMITH, MODERATOR', 'SENATOR KENNEDY', 'MR. NIXON',
#        'MR. FLEMING', 'MR. KENNEDY', 'MR. NOVINS', 'MR. WARREN',
#        'Mr. SMITH', 'MR. VANOCUR', 'Mr. KENNEDY', 'VOICE', 'MR. SM1TH',
#        'FRANK McGEE, MODERATOR', 'MR. NIVEN', 'MR. MORGAN', 'MR. SPIVAK',
#        'MR. LEVY', 'MR. McGEE', 'BILL SHADEL, MODERATOR', 'MR. SHADEL',
#        'MR. VON FREMD', 'MR. CATER', 'MR. DRUMMOND',
#        'QUINCY HOWE, MODERATOR', 'MR. HOWE', 'MR. SINGISER',
#        'MR. EDWARDS', 'MR. CRONKITE', 'MR. CHANCELLOR'], dtype=object)

# %% [markdown]
# ### Determining the speakers who are candidates (through inspecting the previous pieces of information)

# %%
candidates_list = [
    'ADMIRAL STOCKDALE', 
    'ANDERSON', 
    'BENTSEN', 
    'BIDEN', 
    'BUSH', 
    'CHENEY', 
    'CLINTON', 
    'DOLE', 
    'DUKAKIS', 
    'FERRARO', 
    'GORE', 
    'GOV. RONALD REAGAN', 
    'GOVERNOR CLINTON', 
    'HARRIS', 
    'KEMP', 
    'KERRY', 
    'MCCAIN', 
    'MR. CARTER', 
    'MR. FORD', 
    'Mr. KENNEDY', 
    'MR. KENNEDY', 
    'MR. MONDALE', 
    'Mr. NIXON', 
    'MR. NIXON', 
    'MR. REAGAN', 
    'MR.FORD', 
    'MS. KELLY', 
    'OBAM', 
    'OBAMA', 
    'PALIN', 
    'PENCE', 
    'PEROT', 
    'PRESIDENT BUSH', 
    'PRESIDENT GEORGE BUSH', 
    'QUAYLE', 
    'REAGAN', 
    'REP. JOHN B. ANDERSON', 
    'ROMNEHY', 
    'ROMNEY', 
    'ROSS PEROT', 
    'SENATOR GORE', 
    'SENATOR KENNEDY', 
    'STOCKDALE', 
    'THE PRESIDENT', 
    'TRUMP', 
    'VICE PRESIDENT QUAYLE'
]

# %% [markdown]
# ### Keeping only the turns of the candidates

# %%
df_debates_turns = df_debates_turns[df_debates_turns['Speaker'].isin(candidates_list)]
df_debates_turns = df_debates_turns.reset_index(drop=True)

# %%
df_debates_turns
# Out:
#                                      Title  \
# 0     September 29, 2020 Debate Transcript
# 1     September 29, 2020 Debate Transcript
# 2     September 29, 2020 Debate Transcript
# 3     September 29, 2020 Debate Transcript
# 4     September 29, 2020 Debate Transcript
# ...                                    ...
# 3212    October 21, 1960 Debate Transcript
# 3213    October 21, 1960 Debate Transcript
# 3214    October 21, 1960 Debate Transcript
# 3215    October 21, 1960 Debate Transcript
# 3216    October 21, 1960 Debate Transcript
#
#                                                  Debate       Date  \
# 0     Presidential Debate at Case Western Reserve Un... 2020-09-29
# 1     Presidential Debate at Case Western Reserve Un... 2020-09-29
# 2     Presidential Debate at Case Western Reserve Un... 2020-09-29
# 3     Presidential Debate at Case Western Reserve Un... 2020-09-29
# 4     Presidential Debate at Case Western Reserve Un... 2020-09-29
# ...                                                 ...        ...
# 3212       The Fourth Kennedy-Nixon Presidential Debate 1960-10-21
# 3213       The Fourth Kennedy-Nixon Presidential Debate 1960-10-21
# 3214       The Fourth Kennedy-Nixon Presidential Debate 1960-10-21
# 3215       The Fourth Kennedy-Nixon Presidential Debate 1960-10-21
# 3216       The Fourth Kennedy-Nixon Presidential Debate 1960-10-21
#
#                                            Participants  \
# 0     Former Vice President Joe Biden (D) and Presid...
# 1     Former Vice President Joe Biden (D) and Presid...
# 2     Former Vice President Joe Biden (D) and Presid...
# 3     Former Vice President Joe Biden (D) and Presid...
# 4     Former Vice President Joe Biden (D) and Presid...
# ...                                                 ...
# 3212                                      Kennedy-Nixon
# 3213                                      Kennedy-Nixon
# 3214                                      Kennedy-Nixon
# 3215                                      Kennedy-Nixon
# 3216                                      Kennedy-Nixon
#
#                     Moderators      Speaker  \
# 0     Chris Wallace (Fox News)        TRUMP
# 1     Chris Wallace (Fox News)        BIDEN
# 2     Chris Wallace (Fox News)        BIDEN
# 3     Chris Wallace (Fox News)        TRUMP
# 4     Chris Wallace (Fox News)        TRUMP
# ...                        ...          ...
# 3212               QUINCY HOWE    MR. NIXON
# 3213               QUINCY HOWE  MR. KENNEDY
# 3214               QUINCY HOWE  MR. KENNEDY
# 3215               QUINCY HOWE  MR. KENNEDY
# 3216               QUINCY HOWE    MR. NIXON
#
#                                                    Text
# 0     Thank you very much, Chris. I will tell you ve...
# 1     Well, first of all, thank you for doing this a...
# 2     The American people have a right to have a say...
# 3     There aren’t a hundred million people with pre...
# 4     During that period of time, during that period...
# ...                                                 ...
# 3212  I would say that the issue will stay with us a...
# 3213  Well, Mr. Nixon, to go back to 1955. The resol...
# 3214  And that’s the testimony of uh – General Twini...
# 3215  I uh – said that I’ve served this country for ...
# 3216  Senator Kennedy has said tonight again what he...
#
# [3217 rows x 7 columns]

# %% [markdown]
# ## Exporting to a file

# %% [markdown]
# ### JSONL format

# %%
df_debates_turns[['Title', 'Debate', 'Date', 'Participants', 'Moderators', 'Speaker', 'Text']].to_json(f'{output_directory}/debates_turns.jsonl', orient='records', lines=True)

# %% [markdown]
# ### TSV format

# %%
df_debates_turns[['Title', 'Debate', 'Date', 'Participants', 'Moderators', 'Speaker', 'Text']].to_csv(f'{output_directory}/debates_turns.tsv', sep='\t', index=False, encoding='utf-8', lineterminator='\n')
