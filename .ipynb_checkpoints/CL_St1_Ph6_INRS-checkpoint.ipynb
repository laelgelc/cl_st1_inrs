# %% [markdown]
# <center>
# <img src="https://laelgelcpublic.s3.sa-east-1.amazonaws.com/lael_50_years_narrow_white.png.no_years.400px_96dpi.png" width="300" alt="LAEL 50 years logo">
# <h3>APPLIED LINGUISTICS GRADUATE PROGRAMME (LAEL)</h3>
# </center>
# <hr>

# %% [markdown]
# # Corpus Linguistics - Study 1 - Phase 6 - INRS

# %% [markdown]
# This solution automates queries to ChatGPT in the processing of the top-score texts in each dimension.

# %% [markdown]
# ## Required Python packages

# %% [markdown]
# - openai
# - pandas
# - python-dotenv
# - tqdm

# %% [markdown]
# ## Importing the required libraries

# %%
from dotenv import load_dotenv
import openai
import re
import pandas as pd
import os
import sys
import json
import logging
from tqdm import tqdm
import time

# %% [markdown]
# ## Defining input variables

# %%
input_directory = 'cl_st1_ph4_examples'
input_directory_anova = 'cl_st1_inrs_anova'
output_directory = 'cl_st1_ph6_inrs'

# %% [markdown]
# ## Creating output directory

# %%
# Check if the output directory already exists. If it does, do nothing. If it doesn't exist, create it.
if os.path.exists(output_directory):
    print('Output directory already exists.')
else:
    try:
        os.makedirs(output_directory)
        print('Output directory successfully created.')
    except OSError as e:
        print('Failed to create the directory:', e)
        sys.exit(1)

# %% [markdown]
# ## Creating a dictionary that relates the `Dimension-Pole` pair with the `Text ID`s of the respective examples

# %%
# Dictionary to store the parsed data with string keys
dimension_examples = {}

# RegEx pattern to extract Text ID
text_id_pattern = re.compile(r'file = (t\d{6})')

# Mappings for 'Dimension' and 'Pole'
dimension_mapping = {
    'f1': 'Dimension 1',
    'f2': 'Dimension 2',
    'f3': 'Dimension 3',
    'f4': 'Dimension 4',
    'f5': 'Dimension 5',
    'f6': 'Dimension 6'
}

pole_mapping = {
    'neg': 'Negative Pole',
    'pos': 'Positive Pole'
}

# Get the list of files and sort them
files = sorted([f for f in os.listdir(input_directory) if f.endswith('.txt')])

# Iterate over each sorted file in the directory
for filename in files:
    # Extracting 'Dimension' and 'Pole' from the filename
    parts = filename.split('_')
    dimension = dimension_mapping.get(parts[1], parts[1])
    pole = pole_mapping.get(parts[2], parts[2])

    # Opening and reading the file
    with open(os.path.join(input_directory, filename), 'r', encoding='utf-8') as file:
        content = file.read()
        # Find all Text IDs in the file
        text_ids = text_id_pattern.findall(content)
    
    # Construct the dictionary keys and append Text IDs
    for text_id in text_ids:
        key = f"{dimension} - {pole} - {text_id}"
        
        if key not in dimension_examples:
            dimension_examples[key] = {
                'Dimension': dimension,
                'Pole': pole,
                'Host Question': f"{key} - Host Question: <Placeholder for Host Question>",  # Placeholder for the Host Question
                'Dimension Description': f"{key} - Dimension Description:\n<Placeholder for Dimension Description>",  # Placeholder for the Dimension Description
                'Text ID': text_id
            }

# %%
type(dimension_examples)
# Out:
# dict

# %% [markdown]
# ### Exporting to a file

# %%
# Writing the dictionary with string keys to a JSON file
with open(f"{output_directory}/dimension_examples_template.json", 'w') as json_file:
    json.dump(dimension_examples, json_file, indent=4)

# %% [markdown]
# ### Compiling the final `dimension_examples.json` dictionary

# %% [markdown]
# - Copy `dimension_examples_template.json` as `dimension_examples.json`;
# - Complete `dimension_examples.json` with host questions and dimension poles descriptions.

# %% [markdown]
# ## Creating DataFrames according to the definitions in the `dimension_examples.json` dictionary

# %% [markdown]
# ### Loading the `dimension_examples.json` dictionary

# %%
with open(f"{output_directory}/dimension_examples.json", 'r') as json_file:
    dimension_examples = json.load(json_file)

# %% [markdown]
# ### Importing the enriched Target Corpus into a DataFrame

# %%
df_enriched_tc = pd.read_json(f"{input_directory_anova}/debates_turns_parties_scores.jsonl", lines=True)

# %%
df_enriched_tc['Date'] = pd.to_datetime(df_enriched_tc['Date'], unit='ms')

# %%
df_enriched_tc
# Out:
#          File                                 Title  \
# 0     t000000  September 29, 2020 Debate Transcript
# 1     t000001  September 29, 2020 Debate Transcript
# 2     t000002  September 29, 2020 Debate Transcript
# 3     t000003  September 29, 2020 Debate Transcript
# 4     t000004  September 29, 2020 Debate Transcript
# ...       ...                                   ...
# 3423  t003473    October 21, 1960 Debate Transcript
# 3424  t003474    October 21, 1960 Debate Transcript
# 3425  t003475    October 21, 1960 Debate Transcript
# 3426  t003476    October 21, 1960 Debate Transcript
# 3427  t003477    October 21, 1960 Debate Transcript
#
#                                                  Debate       Date  Decade  \
# 0     Presidential Debate at Case Western Reserve Un... 2020-09-29    2020
# 1     Presidential Debate at Case Western Reserve Un... 2020-09-29    2020
# 2     Presidential Debate at Case Western Reserve Un... 2020-09-29    2020
# 3     Presidential Debate at Case Western Reserve Un... 2020-09-29    2020
# 4     Presidential Debate at Case Western Reserve Un... 2020-09-29    2020
# ...                                                 ...        ...     ...
# 3423       The Fourth Kennedy-Nixon Presidential Debate 1960-10-21    1960
# 3424       The Fourth Kennedy-Nixon Presidential Debate 1960-10-21    1960
# 3425       The Fourth Kennedy-Nixon Presidential Debate 1960-10-21    1960
# 3426       The Fourth Kennedy-Nixon Presidential Debate 1960-10-21    1960
# 3427       The Fourth Kennedy-Nixon Presidential Debate 1960-10-21    1960
#
#            Election                                       Participants  \
# 0     2020 Election  Former Vice President Joe Biden (D) and Presid...
# 1     2020 Election  Former Vice President Joe Biden (D) and Presid...
# 2     2020 Election  Former Vice President Joe Biden (D) and Presid...
# 3     2020 Election  Former Vice President Joe Biden (D) and Presid...
# 4     2020 Election  Former Vice President Joe Biden (D) and Presid...
# ...             ...                                                ...
# 3423  1960 Election                                      Kennedy-Nixon
# 3424  1960 Election                                      Kennedy-Nixon
# 3425  1960 Election                                      Kennedy-Nixon
# 3426  1960 Election                                      Kennedy-Nixon
# 3427  1960 Election                                      Kennedy-Nixon
#
#                     Moderators      Speaker       Party  Factor 1  Factor 2  \
# 0     Chris Wallace (Fox News)        TRUMP  Republican         1         8
# 1     Chris Wallace (Fox News)        BIDEN  Democratic         0         1
# 2     Chris Wallace (Fox News)        BIDEN  Democratic        11        11
# 3     Chris Wallace (Fox News)        TRUMP  Republican         1         3
# 4     Chris Wallace (Fox News)        TRUMP  Republican         4         2
# ...                        ...          ...         ...       ...       ...
# 3423               QUINCY HOWE    MR. NIXON  Republican        -7        25
# 3424               QUINCY HOWE  MR. KENNEDY  Democratic         0        25
# 3425               QUINCY HOWE  MR. KENNEDY  Democratic         0         0
# 3426               QUINCY HOWE  MR. KENNEDY  Democratic        12        72
# 3427               QUINCY HOWE    MR. NIXON  Republican         5        50
#
#       Factor 3  Factor 4  Factor 5  Factor 6  \
# 0            0         3         0         3
# 1            0         0         0         0
# 2           -1         5        -7         0
# 3            0         0        -2         0
# 4            0         0        -1         0
# ...        ...       ...       ...       ...
# 3423        -3       -14        -3         0
# 3424         2       -15         0         0
# 3425         0        -1         0         0
# 3426        -4        -7         1        -1
# 3427         1         1        -2         3
#
#                                                    Text
# 0     Thank you very much, Chris. I will tell you ve...
# 1     Well, first of all, thank you for doing this a...
# 2     The American people have a right to have a say...
# 3     There aren’t a hundred million people with pre...
# 4     During that period of time, during that period...
# ...                                                 ...
# 3423  I would say that the issue will stay with us a...
# 3424  Well, Mr. Nixon, to go back to 1955. The resol...
# 3425  And that’s the testimony of uh – General Twini...
# 3426  I uh – said that I’ve served this country for ...
# 3427  Senator Kennedy has said tonight again what he...
#
# [3428 rows x 17 columns]

# %% [markdown]
# ### Creating a DataFrame for each dictionary entry

# %% [markdown]
# - The `df_filtered` DataFrame is explicitly copied using `.copy()` to avoid any `SettingWithCopyWarning`.

# %%
# Initialize an empty DataFrame to store all filtered data
consolidated_df = pd.DataFrame()

# Filtering the 'df_enriched_tc' DataFrame according to the 'dimension_examples' dictionary
for key, value in dimension_examples.items():
    # Filtering the 'df_enriched_tc' DataFrame to only include rows with 'Text ID's from the dictionary entry
    matching_text_ids = [value['Text ID']]
    df_filtered = df_enriched_tc[df_enriched_tc['File'].isin(matching_text_ids)].copy()

    # Adding additional columns as needed
    df_filtered['Dimension'] = value['Dimension']
    df_filtered['Pole'] = value['Pole']
    df_filtered['Host Question'] = value['Host Question']
    df_filtered['Dimension Description'] = value['Dimension Description']

    # Append the filtered DataFrame to the consolidated DataFrame
    consolidated_df = pd.concat([consolidated_df, df_filtered])
    
# Exporting the consolidated DataFrame into a single JSONL document
consolidated_df[['File', 'Title', 'Debate', 'Date', 'Decade', 'Election', 'Participants', 'Moderators', 'Speaker', 'Party', 'Factor 1', 'Factor 2', 'Factor 3', 'Factor 4', 'Factor 5', 'Factor 6', 'Dimension', 'Pole', 'Host Question', 'Dimension Description', 'Text']].to_json(f"{output_directory}/consolidated_dimension_examples.jsonl", orient='records', lines=True)

# %% [markdown]
# #### Importing the DataFrame

# %%
df_dimension_examples = pd.read_json(f"{output_directory}/consolidated_dimension_examples.jsonl", lines=True)
df_dimension_examples['Date'] = pd.to_datetime(df_dimension_examples['Date'], unit='ms')

# %% [markdown]
# ##### Inspecting the DataFrame

# %%
df_dimension_examples
# Out:
#         File                                 Title  \
# 0    t002677    October 13, 1992 Debate Transcript
# 1    t003122    October 11, 1984 Debate Transcript
# 2    t002120     October 5, 2000 Debate Transcript
# 3    t002043            October 3, 2000 Transcript
# 4    t003120    October 11, 1984 Debate Transcript
# ..       ...                                   ...
# 4    Dimension 1 - Negative Pole - t003120 - Host Q...
# ..                                                 ...
# 564  Dimension 6 - Positive Pole - t003113 - Host Q...
# 565  Dimension 6 - Positive Pole - t002910 - Host Q...
# 566  Dimension 6 - Positive Pole - t002393 - Host Q...
# 567  Dimension 6 - Positive Pole - t002362 - Host Q...
# 568  Dimension 6 - Positive Pole - t001942 - Host Q...
#
#                                  Dimension Description  \
# 0    Dimension 1 - Negative Pole - t002677 - Dimens...
# 1    Dimension 1 - Negative Pole - t003122 - Dimens...
# 2    Dimension 1 - Negative Pole - t002120 - Dimens...
# 3    Dimension 1 - Negative Pole - t002043 - Dimens...
# 4    Dimension 1 - Negative Pole - t003120 - Dimens...
# ..                                                 ...
# 564  Dimension 6 - Positive Pole - t003113 - Dimens...
# 565  Dimension 6 - Positive Pole - t002910 - Dimens...
# 566  Dimension 6 - Positive Pole - t002393 - Dimens...
# 567  Dimension 6 - Positive Pole - t002362 - Dimens...
# 568  Dimension 6 - Positive Pole - t001942 - Dimens...
#
#                                                   Text
# 0    This issue is an issue that divides Americans ...
# 1    Let me say first of all I believe very, very s...
# 2    The abortion issue is a very tough one, withou...
# 3    I don’t think a president can do that. I was d...
# 4    I do believe in pluralism. I do believe in sep...
# ..                                                 ...
# 564  With reference to the busing vote that I cast ...
# 565  What troubles me is that when I talk of the vo...
# 566  The differences are very clear. We have a posi...
# 567  Yes. I didn’t favor it when it was in, started...
# 568  Yes, but they didn’t fund the mandates that th...
#
# [569 rows x 21 columns]

# %%
df_dimension_examples.at[50, 'Text']
# Out:
# 'Thank you very much. And let me tell you, you’re absolutely right about part of that, which is I want to bring the rates down, I want to simplify the tax code, and I want to get middle- income taxpayers to have lower taxes. And the reason I want middle-income taxpayers to have lower taxes is because middle-income taxpayers have been buried over the past four years. You’ve seen, as middle-income people in this country, incomes go down $4,300 a family, even as gasoline prices have gone up $2,000. Health insurance premiums, up $2,500. Food prices up. Utility prices up. The middle-income families in America have been crushed over the last four years. So I want to get some relief to middle-income families. That’s part — that’s part one. Now, how about deductions? ‘Cause I’m going to bring rates down across the board for everybody, but I’m going to limit deductions and exemptions and credits, particularly for people at the high end, because I am not going to have people at the high end pay less than they’re paying now. The top 5 percent of taxpayers will continue to pay 60 percent of the income tax the nation collects. So that’ll stay the same. Middle-income people are going to get a tax break. And so, in terms of bringing down deductions, one way of doing that would be say everybody gets — I’ll pick a number — $25,000 of deductions and credits, and you can decide which ones to use. Your home mortgage interest deduction, charity, child tax credit, and so forth, you can use those as part of filling that bucket, if you will, of deductions. But your rate comes down and the burden also comes down on you for one more reason, and that is every middle-income taxpayer no longer will pay any tax on interest, dividends or capital gains. No tax on your savings. That makes life a lot easier. If you’re getting interest from a bank, if you’re getting a statement from a mutual fund or any other kind of investment you have, you don’t have to worry about filing taxes on that, because there’ll be no taxes for anybody making $200,000.00 per year and less, on your interest, dividends and capital gains. Why am I lowering taxes on the middle-class? Because under the last four years, they’ve been buried. And I want to help people in the middle-class. And I will not — I will not under any circumstances, reduce the share that’s being paid by the highest income taxpayers. And I will not, under any circumstances increase taxes on the middle-class. The president’s spending, the president’s borrowing will cost this nation to have to raise taxes on the American people. Not just at the high end. A recent study has shown the people in the middle-class will see $4,000.00 per year in higher taxes as a result of the spending and borrowing of this administration. I will not let that happen. I want to get us on track to a balanced budget, and I’m going to reduce the tax burden on middle income families. And what’s that going to do? It’s going to help those families, and it’s going to create incentives to start growing jobs again in this country.'

# %%
df_dimension_examples.at[50, 'Host Question']
# Out:
# 'Dimension 1 - Positive Pole - t001345 - Host Question: Governor Romney, you have stated that if you’re elected president, you would plan to reduce the tax rates for all the tax brackets and that you would work with the Congress to eliminate some deductions in order to make up for the loss in revenue. Concerning the — these various deductions, the mortgage deductions, the charitable deductions, the child tax credit and also the — oh, what’s that other credit? The education credits, which are important to me, because I have children in college. What would be your position on those things, which are important to the middle class?'

# %%
print(df_dimension_examples.at[50, 'Dimension Description'])
# Out:
# Dimension 1 - Positive Pole - t001345 - Dimension Description:
# 1. **Economic Deregulation and Elite Tax Privilege**: This view advocates for significant tax cuts and regulatory rollbacks favoring high-income earners and corporations, asserting that economic growth is best achieved when the wealthiest individuals and largest businesses have fewer financial obligations. Tax burdens are shifted away from corporations and elites, with policies that allow them to maximize earnings and profits, under the belief that this will eventually stimulate broader economic benefits.
# 2. **Aggressive Growth through High-Spending Initiatives**: Economic expansion is driven by a willingness to take on substantial deficits, promoting large-scale government spending across sectors to catalyze immediate job creation and industrial growth. Fiscal responsibility is deprioritized in favor of rapid economic acceleration, with tax cuts across the board to spur both corporate and consumer spending, often without regard to long-term budget constraints.
# 3. **Tax Minimization for Wealth Creation**: Opposing equitable tax distribution, this stance minimizes tax burdens for high-income groups and corporations, positing that allowing the wealthy to retain more of their earnings promotes greater investment, innovation, and job creation. This ideology accepts that prosperity for lower-income groups will "trickle down" from the economic success of the wealthiest, rather than requiring direct redistributive policies.
# 4. **Corporate Priority over Small Business Support**: This approach prioritizes corporate interests and large enterprises, deeming them more efficient and capable of driving robust economic growth compared to small businesses. It favors policies that support mergers, reduced competition, and incentives for large companies, under the assumption that a thriving corporate sector has the greatest potential to elevate national prosperity.
# 5. **Expanded Government Spending with Minimal Oversight**: Embracing extensive government spending as an economic stimulant, this ideology emphasizes funding large projects and social programs without strict accountability. It suggests that government intervention should not be restricted by concerns of efficiency or waste, as the primary goal is to provide substantial, immediate benefits to the population and economy, even if it leads to increased government influence over economic and social life.
# 6. **Individual Prosperity and Self-Sufficiency**: This dimension advocates for policies that emphasize individual economic responsibility over collective economic initiatives. It minimizes social safety nets and focuses on personal financial autonomy, rejecting the notion that economic policies should ensure equal outcomes. Government support is limited to fostering conditions for individuals to succeed independently, assuming that personal effort and self-reliance are the cornerstones of economic progress.
# These countering components present an ideology that values economic freedom for elites, prioritizes rapid, deficit-driven growth, and emphasizes individual prosperity through deregulation, corporate empowerment, and minimal government intervention in personal financial matters.

# %% [markdown]
# #### Dimension 1 - Positive Pole

# %%
data_set = 'Dimension 1 - Positive Pole'

# %%
df_dim1_pos = df_dimension_examples.iloc[50:100].copy()

# %%
df_dim1_pos.to_json(f"{output_directory}/{data_set}.jsonl", orient='records', lines=True)

# %% [markdown]
# #### Dimension 6 - Negative Pole

# %%
data_set = 'Dimension 6 - Negative Pole'

# %%
df_dim6_neg = df_dimension_examples.iloc[469:519].copy()

# %%
df_dim6_neg.to_json(f"{output_directory}/{data_set}.jsonl", orient='records', lines=True)

# %% [markdown]
# #### Dimension 6 - Positive Pole

# %%
data_set = 'Dimension 6 - Positive Pole'

# %%
df_dim6_pos = df_dimension_examples.iloc[519:569].copy()

# %%
df_dim6_pos.to_json(f"{output_directory}/{data_set}.jsonl", orient='records', lines=True)

# %% [markdown]
# ## Processing the texts with ChatGPT

# %% [markdown]
# ### Defining input variables

# %%
chatgpt_prompt = 'Help me answer the question below by drawing on the dimension below. The dimension captures the ideology underlying political debates broadcast on TV between presidential candidates. Give me an answer that refers to this ideology. Use the description below as a source of information for your answer, and craft your answer in a way that **AGREES** with this description. **PAY ATTENTION TO THE DESCRIPTION AND REPLY USING THE IDEOLOGY AND DISCOURSES**. Write your answer in the register (text variety, genre) of a television political debate, with you as one of the presidential candidates.'

# %%
data_set = 'Dimension 6 - Positive Pole'

# %%
df = pd.read_json(f"{output_directory}/{data_set}.jsonl", lines=True)
df['Date'] = pd.to_datetime(df['Date'], unit='ms')

# %%
df
# Out:
#        File                                           Title  \
# 0   t002261              October 17, 2000 Debate Transcript
# 1   t002076                      October 3, 2000 Transcript
# 2   t002248              October 11, 2000 Debate Transcript
# 3   t002265              October 17, 2000 Debate Transcript
# 4   t001747              October 15, 2008 Debate Transcript
# 5   t002074                      October 3, 2000 Transcript
# 6   t002774  October 15, 1992 Second Half Debate Transcript
# 7   t002772  October 15, 1992 Second Half Debate Transcript
# 8   t001746              October 15, 2008 Debate Transcript
# 9   t003398            September 26, 1960 Debate Transcript
# 10  t002260              October 17, 2000 Debate Transcript
# 11  t002073                      October 3, 2000 Transcript
# 12  t001321              October 16, 2012 Debate Transcript
# 13  t002266              October 17, 2000 Debate Transcript
# 14  t002075                      October 3, 2000 Transcript
# 15  t002112               October 5, 2000 Debate Transcript
# 16  t002365               October 6, 1996 Debate Transcript
# 17  t002111               October 5, 2000 Debate Transcript
# 18  t001913                      October 5, 2004 Transcript
# 19  t001764              October 13, 2004 Debate Transcript
# 20  t002262              October 17, 2000 Debate Transcript
# 21  t001745              October 15, 2008 Debate Transcript
# 22  t002779  October 15, 1992 Second Half Debate Transcript
# 23  t001791              October 13, 2004 Debate Transcript
# 24  t001153               October 3, 2012 Debate Transcript
# 25  t002778  October 15, 1992 Second Half Debate Transcript
# 26  t002363               October 6, 1996 Debate Transcript
# 27  t002290              October 17, 2000 Debate Transcript
# 28  t001615               October 2, 2008 Debate Transcript
# 29  t001149               October 3, 2012 Debate Transcript
# 30  t002367               October 6, 1996 Debate Transcript
# 31  t002291              October 17, 2000 Debate Transcript
# 32  t001351              October 16, 2012 Debate Transcript
# 33  t002771  October 15, 1992 Second Half Debate Transcript
# 31  2000 Election                                          Gore-Bush
# 32  2012 Election  FORMER GOV. MITT ROMNEY, R-MASS. PRESIDENT BAR...
# 33  1992 Election                                 Clinton-Bush-Perot
# 34  1996 Election                                       Clinton-Dole
# 35  2012 Election  FORMER GOV. MITT ROMNEY, R-MASS. PRESIDENT BAR...
# 36  1976 Election                                        Carter-Ford
# 37  1992 Election                              Gore-Quayle-Stockdale
# 38  1992 Election                              Gore-Quayle-Stockdale
# 39  1996 Election                                          Gore-Kemp
# 40  2000 Election                                          Gore-Bush
# 41  2000 Election                                          Gore-Bush
# 42  2012 Election  FORMER GOV. MITT ROMNEY, R-MASS., PRESIDENT BA...
# 43  2012 Election  FORMER GOV. MITT ROMNEY, R-MASS. PRESIDENT BAR...
# 44  1960 Election                                      Kennedy-Nixon
# 45  1984 Election                                       Bush-Ferraro
# 46  1988 Election                                       Bush-Dukakis
# 47  1996 Election                                          Gore-Kemp
# 48  1996 Election                                       Clinton-Dole
# 49  2004 Election  RICHARD B. CHENEY, VICE PRESIDENT OF THE UNITE...
#
#             Moderators      Speaker        Party  ...  Factor 2  Factor 3  \
# 0            MODERATOR         GORE   Democratic  ...         8         0
# 1            MODERATOR         GORE   Democratic  ...         1        -1
# 2            MODERATOR         GORE   Democratic  ...         6         0
# 3            MODERATOR         GORE   Democratic  ...         7         0
# 4        BOB SCHIEFFER        OBAMA   Democratic  ...        12        -1
# 5            MODERATOR         GORE   Democratic  ...        12         0
# 6              SIMPSON        PEROT  independent  ...        23         2
# 7              SIMPSON      CLINTON   Democratic  ...        11         0
# 8        BOB SCHIEFFER       MCCAIN   Republican  ...        10         0
# 9      HOWARD K. SMITH    MR. NIXON   Republican  ...        34       -12
# 10           MODERATOR         BUSH   Republican  ...        14         1
# 11           MODERATOR         BUSH   Republican  ...        10         0
# 12       CANDY CROWLEY       ROMNEY   Republican  ...         9         1
# 13           MODERATOR         BUSH   Republican  ...         8         3
# 14           MODERATOR         BUSH   Republican  ...         7        -1
# 15           MODERATOR    LIEBERMAN   Democratic  ...         9         0
# 16              LEHRER      CLINTON   Democratic  ...         9         0
# 17           MODERATOR       CHENEY   Republican  ...         6         0
# 18          GWEN IFILL       CHENEY   Republican  ...        15        -2
# 19       BOB SCHIEFFER         BUSH   Republican  ...         8         2
# 20           MODERATOR         BUSH   Republican  ...         4        -1
# 21       BOB SCHIEFFER        OBAMA   Democratic  ...        15         0
# 22             SIMPSON      CLINTON   Democratic  ...         1         1
# 23       BOB SCHIEFFER         BUSH   Republican  ...         8        -1
# 24          JIM LEHRER       ROMNEY   Republican  ...        14         0
# 25             SIMPSON         BUSH   Republican  ...         0         0
# 26              LEHRER      CLINTON   Democratic  ...         6         0
# 27           MODERATOR         BUSH   Republican  ...         8         1
# 28          GWEN IFILL        PALIN   Republican  ...         4         0
# 29          JIM LEHRER       ROMNEY   Republican  ...         7         0
# 30              LEHRER      CLINTON   Democratic  ...         5         0
# 31           MODERATOR         GORE   Democratic  ...         7         6
# 32       CANDY CROWLEY        OBAMA   Democratic  ...        10         1
# 44  Dimension 6 - Positive Pole - t003399 - Dimens...
# 45  Dimension 6 - Positive Pole - t003113 - Dimens...
# 46  Dimension 6 - Positive Pole - t002910 - Dimens...
# 47  Dimension 6 - Positive Pole - t002393 - Dimens...
# 48  Dimension 6 - Positive Pole - t002362 - Dimens...
# 49  Dimension 6 - Positive Pole - t001942 - Dimens...
#
#                                                  Text
# 0   We have huge difference between us on this que...
# 1   First of all, I do have mandatory testing. I t...
# 2   Jim, one of the issues that I would like to cl...
# 3   High school. I mentioned before that the local...
# 4   Well, we have a tradition of local control of ...
# 5   We agree on a couple of things on education. I...
# 6   Yes, I’ve got scars to show for being around e...
# 7   First of all, let me say that I’ve spent more ...
# 8   Well, it’s the civil rights issue of the 21st ...
# 9   I’m awfully glad you ge- got that question bec...
# 10  Well, you know, it’s hard to make people love ...
# 11  We can make a huge difference by saying if you...
# 12  Thank you, Jeremy. I appreciate your — your qu...
# 13  When you total up all the federal spending he ...
# 14  The first is, the difference is there is no ne...
# 15  Al Gore and I are committed to making America’...
# 16  I support school choice. I support school choi...
# 17  I think public education is a solution. Our de...
# 18  Well, Gwen, there are several things that I th...
# 19  I’d say, Bob, I’ve got policies to continue to...
# 20  Yeah, I appreciate that. I think any time we e...
# 21  This probably has more to do with our economic...
# 22  Very briefly. Including the parents in the pre...
# 23  Actually, Mitch McConnell had a minimum-wage p...
# 24  Mr. President, Mr. President, you’re entitled ...
# 25  I just had a word of clarification because of ...
# 26  Let me say first of all, I’m all for students ...
# 27  Appreciate that question. Laura and I are prou...
# 28  Say it ain’t so, Joe, there you go again point...
# 29  Well, the primary responsibility for education...
# 30  First of all, Senator Dole, let’s set the reco...
# 31  I care a lot about this. It’s not just movies;...
# 32  Well, Katherine, that’s a great question. And,...
# 33  I’d be delighted to, because you can’t do it t...
# 34  Well, the AmeriCorps program, I must say, if t...
# 35  Let me just finish the point. The — where they...
# 36  Yes, I’d be glad to. In the first place, uh – ...
# 37  I — I come down on the side of freedom of scho...
# 38  And he said that he was not for choosing — giv...
# 39  Thank you very much, Mr. Lehrer. Thanks again ...
# 40  Let me tell you where the biggest discriminati...
# 41  No, I don’t, and I’m not going to go to callin...
# 42  Well, let’s talk about what we need to compete...
# 43  Well, first, I love great schools. Massachuset...
# 44  When uh – the Vice President quotes me in Janu...
# 45  With reference to the busing vote that I cast ...
# 46  What troubles me is that when I talk of the vo...
# 47  The differences are very clear. We have a posi...
# 48  Yes. I didn’t favor it when it was in, started...
# 49  Yes, but they didn’t fund the mandates that th...
#
# [50 rows x 21 columns]

# %%
df.at[49, 'Host Question']
# Out:
# 'Dimension 6 - Positive Pole - t001942 - Host Question: OK, we’ll move on. This goes to Senator Edwards. Flip-flopping has become a recurring theme in this campaign, you may have noticed. Senator Kerry changed his mind about whether to vote to authorize the president to go to war. President Bush changed his mind about whether a homeland security department was a good idea or a 9/11 Commission was a good idea. What’s wrong with a little flip-flop every now and then?'

# %%
print(df.at[49, 'Dimension Description'])
# Out:
# Dimension 6 - Positive Pole - t001942 - Dimension Description:
# 1. **Minimal Accountability and Limited Standardization**: Instead of rigorous standardized testing, this ideology would oppose excessive measurement, advocating that schools and teachers should not be strictly held accountable through testing. It favors flexibility over standardization, trusting individual educators and institutions to operate without enforced accountability measures, thus valuing educational diversity and autonomy over uniformity.
# 2. **Education as a Personal Investment**: Rather than emphasizing equal access, this viewpoint regards education as a personal or family responsibility, where access to quality education is determined by individual means rather than publicly funded equity. It suggests that resources should not be redistributed for equal access, viewing private schooling or homeschooling as viable, self-sustained alternatives for those who can afford it.
# 3. **Local Control without Federal Support**: This approach favors complete local control, viewing federal intervention as unnecessary and potentially intrusive. It believes that communities and local school boards are better positioned to address their needs without reliance on federal funding or oversight, advocating for a minimal role for the federal government in education.
# 4. **Market-Driven Teacher Recruitment and Minimal Regulation**: Opposing centralized hiring policies, this ideology emphasizes market dynamics to attract teachers, with fewer regulations and performance-based pay rather than government-provided incentives. It assumes that good teachers will be naturally attracted to competitive and high-performing schools, with less focus on professional development and more on individual merit and market competition.
# 5. **Parental Control in Early Education**: Rather than universal early childhood education, this viewpoint considers early education as a parental responsibility, emphasizing the right of families to choose or forego early schooling without public provision. It discourages public investment in preschool, viewing early childhood education as an optional, family-driven decision rather than a foundational public service.
# 6. **Reduced Community and Parental Involvement Mandates**: Instead of community and parental involvement in school governance, this ideology holds that schools should operate independently, without heavy reliance on community input. It views schools as institutions for academic instruction rather than community centers, and thus discourages community-driven decision-making in favor of institutional autonomy.
# 7. **Education as a Pathway to Individual Success**: This perspective shifts the focus from societal investment to individual gain, viewing education as a means to personal achievement rather than public good. The ideology emphasizes preparing students for individual success in a competitive economy, valuing personal responsibility and private achievement over social mobility or civic preparation.
# In summary, this reverse dimension would emphasize **individual and family responsibility in education, minimal government involvement, local autonomy without federal aid, and reduced emphasis on social equity or community involvement**. The philosophical underpinnings reflect a belief in **personal responsibility, market-driven solutions, and limited public investment in education**, viewing education primarily as a private matter for individual betterment rather than a shared societal investment.

# %% [markdown]
# ### Querying ChatGPT

# %%
# Setting up logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler(f"{output_directory}/chatgpt_processing.log"),
        logging.StreamHandler()
    ]
)

# Loading all environment variables from `.env` into `os.environ`
load_dotenv()

# Importing the required programme variables from the environment
openai.api_key = os.environ.get('OPENAI_API_KEY', '')
assert openai.api_key

# Defining a function to query ChatGPT with exponential backoff
def get_completion(prompt, model='gpt-4o', max_retries=5):
    client = openai.OpenAI()
    messages = [{'role': 'user', 'content': prompt}]
    for attempt in range(max_retries):
        try:
            response = client.chat.completions.create(
                model=model,
                messages=messages,
                temperature=0
            )
            return response.choices[0].message.content
        except openai.error.RateLimitError as e:
            wait_time = 2 ** attempt  # Exponential backoff
            logging.warning(f"Rate limit exceeded. Retrying in {wait_time} seconds...")
            time.sleep(wait_time)
        except Exception as e:
            logging.error(f"Error querying ChatGPT: {e}")
            return None
    logging.error("Max retries exceeded.")
    return None

# Defining a function to process text using ChatGPT
def process_text(text, prompt_template):
    paragraphs = text.split('\n')  # Split text into paragraphs
    processed_paragraphs = []
    for paragraph in paragraphs:
        prompt = prompt_template + paragraph
        try:
            processed_paragraph = get_completion(prompt)
            if processed_paragraph:
                processed_paragraphs.append(processed_paragraph)
            else:
                processed_paragraphs.append(paragraph)  # Keep original if there's an error
        except Exception as e:
            print(f"Error processing paragraph: {e}")
            processed_paragraphs.append(paragraph)  # Keep original if there's an error
    return '\n'.join(processed_paragraphs)

# Applying the function to the 'Text' column with progress indication
processed_texts = []
for index, row in tqdm(df.iterrows(), total=len(df), desc='Processing texts'):
    # Defining the ChatGPT prompt template
    prompt_template = chatgpt_prompt + '\n' + row['Dimension Description'] + '\n'
    
    # Processing text
    processed_texts.append(process_text(row['Host Question'], prompt_template))

df['Text ChatGPT'] = processed_texts
# Out:
# Processing texts:   0%|          | 0/50 [00:00<?, ?it/s]2024-11-19 17:26:23,091 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:   2%|▏         | 1/50 [00:07<06:20,  7.76s/it]2024-11-19 17:26:30,104 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:   4%|▍         | 2/50 [00:14<05:51,  7.32s/it]2024-11-19 17:26:37,924 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:   6%|▌         | 3/50 [00:22<05:54,  7.55s/it]2024-11-19 17:26:44,499 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:   8%|▊         | 4/50 [00:29<05:29,  7.16s/it]2024-11-19 17:26:49,599 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  10%|█         | 5/50 [00:34<04:48,  6.42s/it]2024-11-19 17:26:55,421 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  12%|█▏        | 6/50 [00:40<04:33,  6.22s/it]2024-11-19 17:27:02,898 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  14%|█▍        | 7/50 [00:47<04:45,  6.63s/it]2024-11-19 17:27:10,138 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  16%|█▌        | 8/50 [00:54<04:46,  6.82s/it]2024-11-19 17:28:04,220 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  18%|█▊        | 9/50 [01:48<14:45, 21.60s/it]2024-11-19 17:28:10,317 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  20%|██        | 10/50 [01:54<11:12, 16.82s/it]2024-11-19 17:28:16,549 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  22%|██▏       | 11/50 [02:01<08:49, 13.57s/it]2024-11-19 17:28:22,514 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  24%|██▍       | 12/50 [02:07<07:07, 11.26s/it]2024-11-19 17:28:27,759 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  26%|██▌       | 13/50 [02:12<05:49,  9.44s/it]2024-11-19 17:28:34,742 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  28%|██▊       | 14/50 [02:19<05:13,  8.70s/it]2024-11-19 17:28:40,317 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  30%|███       | 15/50 [02:24<04:31,  7.76s/it]2024-11-19 17:28:47,130 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  32%|███▏      | 16/50 [02:31<04:14,  7.47s/it]2024-11-19 17:28:54,748 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  34%|███▍      | 17/50 [02:39<04:07,  7.51s/it]2024-11-19 17:28:59,840 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  36%|███▌      | 18/50 [02:44<03:37,  6.79s/it]2024-11-19 17:29:09,149 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  38%|███▊      | 19/50 [02:53<03:53,  7.54s/it]2024-11-19 17:29:15,875 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  40%|████      | 20/50 [03:00<03:38,  7.30s/it]2024-11-19 17:29:25,397 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  42%|████▏     | 21/50 [03:10<03:51,  7.97s/it]2024-11-19 17:29:31,290 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  44%|████▍     | 22/50 [03:15<03:25,  7.34s/it]2024-11-19 17:29:39,279 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  46%|████▌     | 23/50 [03:23<03:23,  7.54s/it]2024-11-19 17:29:45,425 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  48%|████▊     | 24/50 [03:30<03:05,  7.12s/it]2024-11-19 17:29:50,571 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  50%|█████     | 25/50 [03:35<02:43,  6.53s/it]2024-11-19 17:30:01,038 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  52%|█████▏    | 26/50 [03:45<03:05,  7.71s/it]2024-11-19 17:30:05,791 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  54%|█████▍    | 27/50 [03:50<02:36,  6.82s/it]2024-11-19 17:30:14,508 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  56%|█████▌    | 28/50 [03:59<02:42,  7.39s/it]2024-11-19 17:30:21,311 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  58%|█████▊    | 29/50 [04:05<02:31,  7.21s/it]2024-11-19 17:30:27,074 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  60%|██████    | 30/50 [04:11<02:15,  6.78s/it]2024-11-19 17:30:31,889 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  62%|██████▏   | 31/50 [04:16<01:57,  6.19s/it]2024-11-19 17:30:36,489 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  64%|██████▍   | 32/50 [04:21<01:42,  5.71s/it]2024-11-19 17:30:43,660 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  66%|██████▌   | 33/50 [04:28<01:44,  6.15s/it]2024-11-19 17:30:52,154 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  68%|██████▊   | 34/50 [04:36<01:49,  6.85s/it]2024-11-19 17:31:22,120 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  70%|███████   | 35/50 [05:06<03:26, 13.79s/it]2024-11-19 17:31:33,519 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  72%|███████▏  | 36/50 [05:18<03:02, 13.07s/it]2024-11-19 17:31:38,784 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  74%|███████▍  | 37/50 [05:23<02:19, 10.73s/it]2024-11-19 17:31:44,506 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  76%|███████▌  | 38/50 [05:29<01:50,  9.23s/it]2024-11-19 17:31:49,592 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  78%|███████▊  | 39/50 [05:34<01:27,  7.98s/it]2024-11-19 17:31:57,740 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  80%|████████  | 40/50 [05:42<01:20,  8.03s/it]2024-11-19 17:32:03,593 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  82%|████████▏ | 41/50 [05:48<01:06,  7.38s/it]2024-11-19 17:32:10,205 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  84%|████████▍ | 42/50 [05:54<00:57,  7.15s/it]2024-11-19 17:32:16,679 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  86%|████████▌ | 43/50 [06:01<00:48,  6.95s/it]2024-11-19 17:32:23,288 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  88%|████████▊ | 44/50 [06:07<00:41,  6.85s/it]2024-11-19 17:32:31,115 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  90%|█████████ | 45/50 [06:15<00:35,  7.14s/it]2024-11-19 17:32:37,359 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  92%|█████████▏| 46/50 [06:22<00:27,  6.87s/it]2024-11-19 17:32:43,588 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  94%|█████████▍| 47/50 [06:28<00:20,  6.68s/it]2024-11-19 17:32:51,626 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  96%|█████████▌| 48/50 [06:36<00:14,  7.09s/it]2024-11-19 17:32:56,306 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  98%|█████████▊| 49/50 [06:40<00:06,  6.36s/it]2024-11-19 17:33:01,778 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts: 100%|██████████| 50/50 [06:46<00:00,  8.13s/it]

# %% [markdown]
# #### Exporting to a file

# %%
df.to_json(f"{output_directory}/{data_set}-ChatGPT.jsonl", orient='records', lines=True)

# %%
df.to_excel(f"{output_directory}/{data_set}-ChatGPT.xlsx", index=False)

# %% [markdown]
# #### Exporting each text processed by ChatGPT to individual files for inspection

# %%
for index, row in df.iterrows():
    # Constructing the file name based on row data and index
    file_name = f"{output_directory}/{row['Dimension']}_{row['Pole']}_{index}_{row['File']}_chatgpt.txt"
    
    # Writing the 'Host Question' and 'Text ChatGPT' content to the file
    with open(file_name, 'w', encoding='utf-8') as file:
        file.write(row['Host Question'] + '\n\n' + row['Text ChatGPT'])
