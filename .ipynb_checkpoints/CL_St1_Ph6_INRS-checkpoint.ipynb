# %% [markdown]
# <center>
# <img src="https://laelgelcpublic.s3.sa-east-1.amazonaws.com/lael_50_years_narrow_white.png.no_years.400px_96dpi.png" width="300" alt="LAEL 50 years logo">
# <h3>APPLIED LINGUISTICS GRADUATE PROGRAMME (LAEL)</h3>
# </center>
# <hr>

# %% [markdown]
# # Corpus Linguistics - Study 1 - Phase 6 - INRS

# %% [markdown]
# This solution automates queries to ChatGPT in the processing of the top-score texts in each dimension.

# %% [markdown]
# ## Required Python packages

# %% [markdown]
# - pandas

# %% [markdown]
# ## Importing the required libraries

# %%
from dotenv import load_dotenv
import openai
import re
import pandas as pd
import os
import sys
import json
import logging
from tqdm import tqdm
import time

# %% [markdown]
# ## Defining input variables

# %%
input_directory = 'cl_st1_ph4_examples'
input_directory_anova = 'cl_st1_inrs_anova'
output_directory = 'cl_st1_ph6_inrs'

# %% [markdown]
# ## Creating output directory

# %%
# Check if the output directory already exists. If it does, do nothing. If it doesn't exist, create it.
if os.path.exists(output_directory):
    print('Output directory already exists.')
else:
    try:
        os.makedirs(output_directory)
        print('Output directory successfully created.')
    except OSError as e:
        print('Failed to create the directory:', e)
        sys.exit(1)

# %% [markdown]
# ## Creating a dictionary that relates the `Dimension-Pole` pair with the `Text ID`s of the respective examples

# %%
# Dictionary to store the parsed data with string keys
dimension_examples = {}

# RegEx pattern to extract Text ID
text_id_pattern = re.compile(r'file = (t\d{6})')

# Mappings for 'Dimension' and 'Pole'
dimension_mapping = {
    'f1': 'Dimension 1',
    'f2': 'Dimension 2',
    'f3': 'Dimension 3',
    'f4': 'Dimension 4',
    'f5': 'Dimension 5',
    'f6': 'Dimension 6'
}

pole_mapping = {
    'neg': 'Negative Pole',
    'pos': 'Positive Pole'
}

# Get the list of files and sort them
files = sorted([f for f in os.listdir(input_directory) if f.endswith('.txt')])

# Iterate over each sorted file in the directory
for filename in files:
    # Extracting 'Dimension' and 'Pole' from the filename
    parts = filename.split('_')
    dimension = dimension_mapping.get(parts[1], parts[1])
    pole = pole_mapping.get(parts[2], parts[2])

    # Opening and reading the file
    with open(os.path.join(input_directory, filename), 'r', encoding='utf-8') as file:
        content = file.read()
        # Find all Text IDs in the file
        text_ids = text_id_pattern.findall(content)
    
    # Construct the dictionary keys and append Text IDs
    for text_id in text_ids:
        key = f"{dimension} - {pole} - {text_id}"
        
        if key not in dimension_examples:
            dimension_examples[key] = {
                'Dimension': dimension,
                'Pole': pole,
                'Host Question': f"{key} - Host Question: <Placeholder for Host Question>",  # Placeholder for the Host Question
                'Dimension Description': f"{key} - Dimension Description:\n<Placeholder for Dimension Description>",  # Placeholder for the Dimension Description
                'Text ID': text_id
            }

# %%
type(dimension_examples)
# Out:
# dict

# %% [markdown]
# ### Exporting to a file

# %%
# Writing the dictionary with string keys to a JSON file
with open(f"{output_directory}/dimension_examples_template.json", 'w') as json_file:
    json.dump(dimension_examples, json_file, indent=4)

# %% [markdown]
# ### Compiling the final `dimension_examples.json` dictionary

# %% [markdown]
# - Copy `dimension_examples_template.json` as `dimension_examples.json`;
# - Complete `dimension_examples.json` with host questions and dimension poles descriptions.

# %% [markdown]
# ## Creating DataFrames according to the definitions in the `dimension_examples.json` dictionary

# %% [markdown]
# ### Loading the `dimension_examples.json` dictionary

# %%
with open(f"{output_directory}/dimension_examples.json", 'r') as json_file:
    dimension_examples = json.load(json_file)

# %% [markdown]
# ### Importing the enriched Target Corpus into a DataFrame

# %%
df_enriched_tc = pd.read_json(f"{input_directory_anova}/debates_turns_parties_scores.jsonl", lines=True)

# %%
df_enriched_tc['Date'] = pd.to_datetime(df_enriched_tc['Date'], unit='ms')

# %%
df_enriched_tc
# Out:
#          File                                 Title  \
# 0     t000000  September 29, 2020 Debate Transcript
# 1     t000001  September 29, 2020 Debate Transcript
# 2     t000002  September 29, 2020 Debate Transcript
# 3     t000003  September 29, 2020 Debate Transcript
# 4     t000004  September 29, 2020 Debate Transcript
# ...       ...                                   ...
# 3423  t003473    October 21, 1960 Debate Transcript
# 3424  t003474    October 21, 1960 Debate Transcript
# 3425  t003475    October 21, 1960 Debate Transcript
# 3426  t003476    October 21, 1960 Debate Transcript
# 3427  t003477    October 21, 1960 Debate Transcript
#
#                                                  Debate       Date  Decade  \
# 0     Presidential Debate at Case Western Reserve Un... 2020-09-29    2020
# 1     Presidential Debate at Case Western Reserve Un... 2020-09-29    2020
# 2     Presidential Debate at Case Western Reserve Un... 2020-09-29    2020
# 3     Presidential Debate at Case Western Reserve Un... 2020-09-29    2020
# 4     Presidential Debate at Case Western Reserve Un... 2020-09-29    2020
# ...                                                 ...        ...     ...
# 3423       The Fourth Kennedy-Nixon Presidential Debate 1960-10-21    1960
# 3424       The Fourth Kennedy-Nixon Presidential Debate 1960-10-21    1960
# 3425       The Fourth Kennedy-Nixon Presidential Debate 1960-10-21    1960
# 3426       The Fourth Kennedy-Nixon Presidential Debate 1960-10-21    1960
# 3427       The Fourth Kennedy-Nixon Presidential Debate 1960-10-21    1960
#
#            Election                                       Participants  \
# 0     2020 Election  Former Vice President Joe Biden (D) and Presid...
# 1     2020 Election  Former Vice President Joe Biden (D) and Presid...
# 2     2020 Election  Former Vice President Joe Biden (D) and Presid...
# 3     2020 Election  Former Vice President Joe Biden (D) and Presid...
# 4     2020 Election  Former Vice President Joe Biden (D) and Presid...
# ...             ...                                                ...
# 3423  1960 Election                                      Kennedy-Nixon
# 3424  1960 Election                                      Kennedy-Nixon
# 3425  1960 Election                                      Kennedy-Nixon
# 3426  1960 Election                                      Kennedy-Nixon
# 3427  1960 Election                                      Kennedy-Nixon
#
#                     Moderators      Speaker       Party  Factor 1  Factor 2  \
# 0     Chris Wallace (Fox News)        TRUMP  Republican         1         8
# 1     Chris Wallace (Fox News)        BIDEN  Democratic         0         1
# 2     Chris Wallace (Fox News)        BIDEN  Democratic        11        11
# 3     Chris Wallace (Fox News)        TRUMP  Republican         1         3
# 4     Chris Wallace (Fox News)        TRUMP  Republican         4         2
# ...                        ...          ...         ...       ...       ...
# 3423               QUINCY HOWE    MR. NIXON  Republican        -7        25
# 3424               QUINCY HOWE  MR. KENNEDY  Democratic         0        25
# 3425               QUINCY HOWE  MR. KENNEDY  Democratic         0         0
# 3426               QUINCY HOWE  MR. KENNEDY  Democratic        12        72
# 3427               QUINCY HOWE    MR. NIXON  Republican         5        50
#
#       Factor 3  Factor 4  Factor 5  Factor 6  \
# 0            0         3         0         3
# 1            0         0         0         0
# 2           -1         5        -7         0
# 3            0         0        -2         0
# 4            0         0        -1         0
# ...        ...       ...       ...       ...
# 3423        -3       -14        -3         0
# 3424         2       -15         0         0
# 3425         0        -1         0         0
# 3426        -4        -7         1        -1
# 3427         1         1        -2         3
#
#                                                    Text
# 0     Thank you very much, Chris. I will tell you ve...
# 1     Well, first of all, thank you for doing this a...
# 2     The American people have a right to have a say...
# 3     There aren’t a hundred million people with pre...
# 4     During that period of time, during that period...
# ...                                                 ...
# 3423  I would say that the issue will stay with us a...
# 3424  Well, Mr. Nixon, to go back to 1955. The resol...
# 3425  And that’s the testimony of uh – General Twini...
# 3426  I uh – said that I’ve served this country for ...
# 3427  Senator Kennedy has said tonight again what he...
#
# [3428 rows x 17 columns]

# %% [markdown]
# ### Creating a DataFrame for each dictionary entry

# %% [markdown]
# - The `df_filtered` DataFrame is explicitly copied using `.copy()` to avoid any `SettingWithCopyWarning`.

# %%
# Initialize an empty DataFrame to store all filtered data
consolidated_df = pd.DataFrame()

# Filtering the 'df_enriched_tc' DataFrame according to the 'dimension_examples' dictionary
for key, value in dimension_examples.items():
    # Filtering the 'df_enriched_tc' DataFrame to only include rows with 'Text ID's from the dictionary entry
    matching_text_ids = [value['Text ID']]
    df_filtered = df_enriched_tc[df_enriched_tc['File'].isin(matching_text_ids)].copy()

    # Adding additional columns as needed
    df_filtered['Dimension'] = value['Dimension']
    df_filtered['Pole'] = value['Pole']
    df_filtered['Host Question'] = value['Host Question']
    df_filtered['Dimension Description'] = value['Dimension Description']

    # Append the filtered DataFrame to the consolidated DataFrame
    consolidated_df = pd.concat([consolidated_df, df_filtered])
    
# Exporting the consolidated DataFrame into a single JSONL document
consolidated_df[['File', 'Title', 'Debate', 'Date', 'Decade', 'Election', 'Participants', 'Moderators', 'Speaker', 'Party', 'Factor 1', 'Factor 2', 'Factor 3', 'Factor 4', 'Factor 5', 'Factor 6', 'Dimension', 'Pole', 'Host Question', 'Dimension Description', 'Text']].to_json(f"{output_directory}/consolidated_dimension_examples.jsonl", orient='records', lines=True)

# %% [markdown]
# #### Importing the DataFrame

# %%
df_dimension_examples = pd.read_json(f"{output_directory}/consolidated_dimension_examples.jsonl", lines=True)
df_dimension_examples['Date'] = pd.to_datetime(df_dimension_examples['Date'], unit='ms')

# %% [markdown]
# ##### Inspecting the DataFrame

# %%
df_dimension_examples
# Out:
#         File                                 Title  \
# 0    t002677    October 13, 1992 Debate Transcript
# 1    t003122    October 11, 1984 Debate Transcript
# 2    t002120     October 5, 2000 Debate Transcript
# 3    t002043            October 3, 2000 Transcript
# 4    t003120    October 11, 1984 Debate Transcript
# ..       ...                                   ...
# 564  t003113    October 11, 1984 Debate Transcript
# 565  t002910  September 25, 1988 Debate Transcript
# 566  t002393     October 9, 1996 Debate Transcript
# 567  t002362     October 6, 1996 Debate Transcript
# 568  t001942            October 5, 2004 Transcript
# 567  Dimension 6 - Positive Pole - t002362 - Host Q...
# 568  Dimension 6 - Positive Pole - t001942 - Host Q...
#
#                                  Dimension Description  \
# 0    Dimension 1 - Negative Pole - t002677 - Dimens...
# 1    Dimension 1 - Negative Pole - t003122 - Dimens...
# 2    Dimension 1 - Negative Pole - t002120 - Dimens...
# 3    Dimension 1 - Negative Pole - t002043 - Dimens...
# 4    Dimension 1 - Negative Pole - t003120 - Dimens...
# ..                                                 ...
# 564  Dimension 6 - Positive Pole - t003113 - Dimens...
# 565  Dimension 6 - Positive Pole - t002910 - Dimens...
# 566  Dimension 6 - Positive Pole - t002393 - Dimens...
# 567  Dimension 6 - Positive Pole - t002362 - Dimens...
# 568  Dimension 6 - Positive Pole - t001942 - Dimens...
#
#                                                   Text
# 0    This issue is an issue that divides Americans ...
# 1    Let me say first of all I believe very, very s...
# 2    The abortion issue is a very tough one, withou...
# 3    I don’t think a president can do that. I was d...
# 4    I do believe in pluralism. I do believe in sep...
# ..                                                 ...
# 564  With reference to the busing vote that I cast ...
# 565  What troubles me is that when I talk of the vo...
# 566  The differences are very clear. We have a posi...
# 567  Yes. I didn’t favor it when it was in, started...
# 568  Yes, but they didn’t fund the mandates that th...
#
# [569 rows x 21 columns]

# %%
df_dimension_examples.at[50, 'Text']
# Out:
# 'Thank you very much. And let me tell you, you’re absolutely right about part of that, which is I want to bring the rates down, I want to simplify the tax code, and I want to get middle- income taxpayers to have lower taxes. And the reason I want middle-income taxpayers to have lower taxes is because middle-income taxpayers have been buried over the past four years. You’ve seen, as middle-income people in this country, incomes go down $4,300 a family, even as gasoline prices have gone up $2,000. Health insurance premiums, up $2,500. Food prices up. Utility prices up. The middle-income families in America have been crushed over the last four years. So I want to get some relief to middle-income families. That’s part — that’s part one. Now, how about deductions? ‘Cause I’m going to bring rates down across the board for everybody, but I’m going to limit deductions and exemptions and credits, particularly for people at the high end, because I am not going to have people at the high end pay less than they’re paying now. The top 5 percent of taxpayers will continue to pay 60 percent of the income tax the nation collects. So that’ll stay the same. Middle-income people are going to get a tax break. And so, in terms of bringing down deductions, one way of doing that would be say everybody gets — I’ll pick a number — $25,000 of deductions and credits, and you can decide which ones to use. Your home mortgage interest deduction, charity, child tax credit, and so forth, you can use those as part of filling that bucket, if you will, of deductions. But your rate comes down and the burden also comes down on you for one more reason, and that is every middle-income taxpayer no longer will pay any tax on interest, dividends or capital gains. No tax on your savings. That makes life a lot easier. If you’re getting interest from a bank, if you’re getting a statement from a mutual fund or any other kind of investment you have, you don’t have to worry about filing taxes on that, because there’ll be no taxes for anybody making $200,000.00 per year and less, on your interest, dividends and capital gains. Why am I lowering taxes on the middle-class? Because under the last four years, they’ve been buried. And I want to help people in the middle-class. And I will not — I will not under any circumstances, reduce the share that’s being paid by the highest income taxpayers. And I will not, under any circumstances increase taxes on the middle-class. The president’s spending, the president’s borrowing will cost this nation to have to raise taxes on the American people. Not just at the high end. A recent study has shown the people in the middle-class will see $4,000.00 per year in higher taxes as a result of the spending and borrowing of this administration. I will not let that happen. I want to get us on track to a balanced budget, and I’m going to reduce the tax burden on middle income families. And what’s that going to do? It’s going to help those families, and it’s going to create incentives to start growing jobs again in this country.'

# %%
df_dimension_examples.at[50, 'Host Question']
# Out:
# 'Dimension 1 - Positive Pole - t001345 - Host Question: Governor Romney, you have stated that if you’re elected president, you would plan to reduce the tax rates for all the tax brackets and that you would work with the Congress to eliminate some deductions in order to make up for the loss in revenue. Concerning the — these various deductions, the mortgage deductions, the charitable deductions, the child tax credit and also the — oh, what’s that other credit? The education credits, which are important to me, because I have children in college. What would be your position on those things, which are important to the middle class?'

# %%
print(df_dimension_examples.at[50, 'Dimension Description'])
# Out:
# Dimension 1 - Positive Pole - t001345 - Dimension Description:
# 1. **Economic Deregulation and Elite Tax Privilege**: This view advocates for significant tax cuts and regulatory rollbacks favoring high-income earners and corporations, asserting that economic growth is best achieved when the wealthiest individuals and largest businesses have fewer financial obligations. Tax burdens are shifted away from corporations and elites, with policies that allow them to maximize earnings and profits, under the belief that this will eventually stimulate broader economic benefits.
# 2. **Aggressive Growth through High-Spending Initiatives**: Economic expansion is driven by a willingness to take on substantial deficits, promoting large-scale government spending across sectors to catalyze immediate job creation and industrial growth. Fiscal responsibility is deprioritized in favor of rapid economic acceleration, with tax cuts across the board to spur both corporate and consumer spending, often without regard to long-term budget constraints.
# 3. **Tax Minimization for Wealth Creation**: Opposing equitable tax distribution, this stance minimizes tax burdens for high-income groups and corporations, positing that allowing the wealthy to retain more of their earnings promotes greater investment, innovation, and job creation. This ideology accepts that prosperity for lower-income groups will "trickle down" from the economic success of the wealthiest, rather than requiring direct redistributive policies.
# 4. **Corporate Priority over Small Business Support**: This approach prioritizes corporate interests and large enterprises, deeming them more efficient and capable of driving robust economic growth compared to small businesses. It favors policies that support mergers, reduced competition, and incentives for large companies, under the assumption that a thriving corporate sector has the greatest potential to elevate national prosperity.
# 5. **Expanded Government Spending with Minimal Oversight**: Embracing extensive government spending as an economic stimulant, this ideology emphasizes funding large projects and social programs without strict accountability. It suggests that government intervention should not be restricted by concerns of efficiency or waste, as the primary goal is to provide substantial, immediate benefits to the population and economy, even if it leads to increased government influence over economic and social life.
# 6. **Individual Prosperity and Self-Sufficiency**: This dimension advocates for policies that emphasize individual economic responsibility over collective economic initiatives. It minimizes social safety nets and focuses on personal financial autonomy, rejecting the notion that economic policies should ensure equal outcomes. Government support is limited to fostering conditions for individuals to succeed independently, assuming that personal effort and self-reliance are the cornerstones of economic progress.
# These countering components present an ideology that values economic freedom for elites, prioritizes rapid, deficit-driven growth, and emphasizes individual prosperity through deregulation, corporate empowerment, and minimal government intervention in personal financial matters.

# %% [markdown]
# #### Dimension 1 - Positive Pole

# %%
data_set = 'Dimension 1 - Positive Pole'

# %%
df_dim1_pos = df_dimension_examples.iloc[50:100].copy()

# %%
df_dim1_pos.to_json(f"{output_directory}/{data_set}.jsonl", orient='records', lines=True)

# %% [markdown]
# #### Dimension 6 - Negative Pole

# %%
data_set = 'Dimension 6 - Negative Pole'

# %%
df_dim6_neg = df_dimension_examples.iloc[469:519].copy()

# %%
df_dim6_neg.to_json(f"{output_directory}/{data_set}.jsonl", orient='records', lines=True)

# %% [markdown]
# #### Dimension 6 - Positive Pole

# %%
data_set = 'Dimension 6 - Positive Pole'

# %%
df_dim6_pos = df_dimension_examples.iloc[519:569].copy()

# %%
df_dim6_pos.to_json(f"{output_directory}/{data_set}.jsonl", orient='records', lines=True)

# %% [markdown]
# ## Processing the texts with ChatGPT

# %% [markdown]
# ### Defining input variables

# %%
chatgpt_prompt = 'Help me answer the question below by drawing on the dimension below. The dimension captures the ideology underlying political debates broadcast on TV between presidential candidates. Give me an answer that refers to this ideology. Use the description below as a source of information for your answer, and craft your answer in a way that **AGREES** with this description. **PAY ATTENTION TO THE DESCRIPTION AND REPLY USING THE IDEOLOGY AND DISCOURSES**. Write your answer in the register (text variety, genre) of a television political debate, with you as one of the presidential candidates.'

# %%
data_set = 'Dimension 6 - Negative Pole'

# %%
df = pd.read_json(f"{output_directory}/{data_set}.jsonl", lines=True)
df['Date'] = pd.to_datetime(df['Date'], unit='ms')

# %%
df
# Out:
#        File                                              Title  \
# 0   t003283               September 23, 1976 Debate Transcript
# 1   t003448                 October 13, 1960 Debate Transcript
# 2   t001624                  October 2, 2008 Debate Transcript
# 3   t003432                  October 7, 1960 Debate Transcript
# 4   t003434                 October 13, 1960 Debate Transcript
# 5   t001879                         October 5, 2004 Transcript
# 6   t002809                 October 19, 1992 Debate Transcript
# 7   t002967                 October 5, 1988 Debate Transcripts
# 8   t003282               September 23, 1976 Debate Transcript
# 9   t003359                 October 22, 1976 Debate Transcript
# 10  t003389               September 26, 1960 Debate Transcript
# 11  t000303  October 07, 2020 Vice Presidential Debate Tran...
# 12  t000907                  October 9, 2016 Debate Transcript
# 13  t000911                  October 9, 2016 Debate Transcript
# 14  t001415                 October 22, 2012 Debate Transcript
# 15  t002131                  October 5, 2000 Debate Transcript
# 16  t002333                  October 6, 1996 Debate Transcript
# 17  t002352                  October 6, 1996 Debate Transcript
# 18  t002405                  October 9, 1996 Debate Transcript
# 19  t002409                  October 9, 1996 Debate Transcript
# 20  t002521                 October 16, 1996 Debate Transcript
# 21  t002867                 October 19, 1992 Debate Transcript
# 22  t002952                 October 5, 1988 Debate Transcripts
# 23  t002987                 October 5, 1988 Debate Transcripts
# 24  t003390               September 26, 1960 Debate Transcript
# 25  t000008               September 29, 2020 Debate Transcript
# 26  t000759                  October 4, 2016 Debate Transcript
# 27  t000771                  October 4, 2016 Debate Transcript
# 28  t000836                  October 4, 2016 Debate Transcript
# 29  t000922                  October 9, 2016 Debate Transcript
# 30  t001157                  October 3, 2012 Debate Transcript
# 31  t001158                  October 3, 2012 Debate Transcript
# 32  t001195                 October 11, 2012 Debate Transcript
# 33  t001418                 October 22, 2012 Debate Transcript
# 34  t001567                  October 2, 2008 Debate Transcript
# 35  t001609                  October 2, 2008 Debate Transcript
# 36  t001651                  October 7, 2008 Debate Transcript
# 37  t001724                 October 15, 2008 Debate Transcript
# 38  t001826                  October 8, 2004 Debate Transcript
# 39  t001888                         October 5, 2004 Transcript
# 40  t001996               September 30. 2004 Debate Transcript
# 41  t002140                  October 5, 2000 Debate Transcript
# 37  2008 Election  U.S. SENATOR JOHN MCCAIN (AZ)REPUBLICAN PRESID...
# 38  2004 Election  GEORGE W. BUSHPRESIDENT OF THE UNITED STATES U...
# 39  2004 Election  RICHARD B. CHENEY, VICE PRESIDENT OF THE UNITE...
# 40  2004 Election  GEORGE W. BUSH, PRESIDENT OF THE UNITED STATES...
# 41  2000 Election                                   Lieberman-Cheney
# 42  2000 Election                                   Lieberman-Cheney
# 43  2000 Election                                          Gore-Bush
# 44  2000 Election                                          Gore-Bush
# 45  2000 Election                                          Gore-Bush
# 46  2000 Election                                          Gore-Bush
# 47  2000 Election                                          Gore-Bush
# 48  1996 Election                                       Clinton-Dole
# 49  1996 Election                                          Gore-Kemp
#
#                                            Moderators      Speaker  \
# 0                                        EDWIN NEWMAN     MR. FORD
# 1                                         BILL SHADEL  MR. KENNEDY
# 2                                          GWEN IFILL        PALIN
# 3                                         FRANK McGEE  MR. KENNEDY
# 4                                         BILL SHADEL    MR. NIXON
# 5                                          GWEN IFILL       CHENEY
# 6                                          JIM LEHRER         BUSH
# 7                                            WOODRUFF       QUAYLE
# 8                                        EDWIN NEWMAN     MR. FORD
# 9                                         MS. WALTERS     MR. FORD
# 10                                    HOWARD K. SMITH  MR. KENNEDY
# 11                             Susan Page (USA Today)        PENCE
# 12  Anderson Cooper (CNN) and Martha Raddatz (ABC ...        TRUMP
# 13  Anderson Cooper (CNN) and Martha Raddatz (ABC ...        TRUMP
# 14                                      BOB SCHIEFFER       ROMNEY
# 15                                          MODERATOR    LIEBERMAN
# 16                                             LEHRER      CLINTON
# 17                                             LEHRER         DOLE
# 18                                             LEHRER         GORE
# 19                                             LEHRER         GORE
# 20                                             LEHRER         DOLE
# 21                                         JIM LEHRER         BUSH
# 22                                           WOODRUFF       QUAYLE
# 23                                           WOODRUFF       QUAYLE
# 24                                    HOWARD K. SMITH    MR. NIXON
# 25                           Chris Wallace (Fox News)        TRUMP
# 26                          Elaine Quijano (CBS News)        KAINE
# 27                          Elaine Quijano (CBS News)        PENCE
# 28                          Elaine Quijano (CBS News)        PENCE
# 29  Anderson Cooper (CNN) and Martha Raddatz (ABC ...      CLINTON
# 30                                         JIM LEHRER        OBAMA
# 31                                         JIM LEHRER        OBAMA
# 32                                     MARTHA RADDATZ         RYAN
# 33                                      BOB SCHIEFFER       ROMNEY
# 34                                         GWEN IFILL        PALIN
# 35                                         GWEN IFILL        BIDEN
# 36                                         TOM BROKAW       MCCAIN
# 37                                      BOB SCHIEFFER       MCCAIN
# 38                                     CHARLES GIBSON         BUSH
# 39                                         GWEN IFILL      EDWARDS
# 40                                         JIM LEHRER         BUSH
# 41                                          MODERATOR    LIEBERMAN
# 42                                          MODERATOR    LIEBERMAN
# 43                                          MODERATOR         BUSH
# 44                                          MODERATOR         GORE
# 45                                          MODERATOR         GORE
# 46                                          MODERATOR         BUSH
# 47                                          MODERATOR         GORE
# 48                                             LEHRER      CLINTON
# 49                                             LEHRER         KEMP
#
#          Party  ...  Factor 2  Factor 3  Factor 4  Factor 5  Factor 6  \
# 0   Republican  ...         4         0        -1         0        -6
# 1   Democratic  ...        27         2         1        -5        -6
# 2   Republican  ...        10         0         3         0        -5
# 3   Democratic  ...        14        -1         0         0        -5
# 4   Republican  ...        28         1        -1         0        -5
# 5   Republican  ...        10        12         3         0        -4
# 6   Republican  ...         9        -3         3         0        -4
# 7   Republican  ...         5        -1         0         0        -4
# 8   Republican  ...         3         0         0        -1        -4
# 9   Republican  ...        13         0         1         1        -4
# 10  Democratic  ...        16         0         0         1        -4
# 11  Republican  ...        10         0         3         2        -3
# 12  Republican  ...         5         0         0         0        -3
# 13  Republican  ...         5         1         0         0        -3
# 14  Republican  ...        24         4         1        -1        -3
# 15  Democratic  ...        17         6         2        -1        -3
# 16  Democratic  ...         9         0         2        -1        -3
# 17  Republican  ...         3         0         1         0        -3
# 18  Democratic  ...         6         0         0         0        -3
# 19  Democratic  ...         4         0         3         0        -3
# 20  Republican  ...         7         1         0         8        -3
# 21  Republican  ...         9        -2         1         0        -3
# 22  Republican  ...         4        -1         0         0        -3
# 23  Republican  ...         3         0         0         0        -3
# 24  Republican  ...        10         0         1        -7        -3
# 25  Republican  ...         0         0         0         0        -2
# 26  Democratic  ...         8        -1        -1         0        -2
# 27  Republican  ...         9         2         0         0        -2
# 28  Republican  ...         7        -4        13         0        -2
# 29  Democratic  ...        15         9        -2        -1        -2
# 30  Democratic  ...        11         2         1         2        -2
# 31  Democratic  ...         0         0         0         0        -2
# 32  Republican  ...         3         0         0         0        -2
# 33  Republican  ...         6         0         0         1        -2
# 34  Republican  ...         8         0         2         1        -2
# 35  Democratic  ...        17         3         3        -1        -2
# 36  Republican  ...        12        -1         0        -1        -2
# 37  Republican  ...         7         2         4         6        -2
# 38  Republican  ...         8         4         0        -1        -2
# 39  Democratic  ...         5        10         0         0        -2
# 40  Republican  ...         7         4         0        -1        -2
# 41  Democratic  ...        22         3         6         0        -2
# 42  Democratic  ...         9        -2         3        -2        -2
# 43  Republican  ...         6         2         0         0        -2
# 44  Democratic  ...        19         2         3        -3        -2
# 45  Democratic  ...         3         0         7         0        -2
# 46  Republican  ...         3         0         1        -1        -2
# 47  Democratic  ...        11        -3         3         5        -2
# 48  Democratic  ...         1         0         0         0        -2
# 49  Republican  ...         2        -1         2         0        -2
#
#       Dimension           Pole  \
# 0   Dimension 6  Negative Pole
# 1   Dimension 6  Negative Pole
# 2   Dimension 6  Negative Pole
# 3   Dimension 6  Negative Pole
# 4   Dimension 6  Negative Pole
# 5   Dimension 6  Negative Pole
# 6   Dimension 6  Negative Pole
# 7   Dimension 6  Negative Pole
# 8   Dimension 6  Negative Pole
# 9   Dimension 6  Negative Pole
# 10  Dimension 6  Negative Pole
# 11  Dimension 6  Negative Pole
# 12  Dimension 6  Negative Pole
# 13  Dimension 6  Negative Pole
# 14  Dimension 6  Negative Pole
# 15  Dimension 6  Negative Pole
# 16  Dimension 6  Negative Pole
# 17  Dimension 6  Negative Pole
# 18  Dimension 6  Negative Pole
# 19  Dimension 6  Negative Pole
# 20  Dimension 6  Negative Pole
# 21  Dimension 6  Negative Pole
# 22  Dimension 6  Negative Pole
# 23  Dimension 6  Negative Pole
# 38  Dimension 6 - Negative Pole - t001826 - Dimens...
# 39  Dimension 6 - Negative Pole - t001888 - Dimens...
# 40  Dimension 6 - Negative Pole - t001996 - Dimens...
# 41  Dimension 6 - Negative Pole - t002140 - Dimens...
# 42  Dimension 6 - Negative Pole - t002149 - Dimens...
# 43  Dimension 6 - Negative Pole - t002167 - Dimens...
# 44  Dimension 6 - Negative Pole - t002175 - Dimens...
# 45  Dimension 6 - Negative Pole - t002199 - Dimens...
# 46  Dimension 6 - Negative Pole - t002255 - Dimens...
# 47  Dimension 6 - Negative Pole - t002286 - Dimens...
# 48  Dimension 6 - Negative Pole - t002349 - Dimens...
# 49  Dimension 6 - Negative Pole - t002406 - Dimens...
#
#                                                  Text
# 0   That tax bill does not entirely meet the crite...
# 1   Well, I always have difficulty recognizing my ...
# 2   People aren’t looking for more of the same. Th...
# 3   Well, let me say I do think that parties are i...
# 4   Yes. As a matter of fact, the statement that S...
# 5   Gwen, I want to thank you, and I want to thank...
# 6   Governor Clinton has to operate under a balanc...
# 7   He disbanded the club, but he’s still got the ...
# 8   At the time, Mr. Gannon, that I made the recom...
# 9   Well, Mr. uh – Nelson, uh – I testified before...
# 10  Well, the Vice President and I came to the Con...
# 11  As I said, Susan, the climate is changing. We’...
# 12  Well, one thing I’d do is get rid of carried i...
# 13  A lot of my—excuse me, Anderson—a lot of my wr...
# 14  Well, let’s step back and talk about what’s ha...
# 15  It would, of course, be a very serious situati...
# 16  Mr. Lehrer, I hope we’ll have a chance to disc...
# 17  Well, many of the provisions in the Kassebaum ...
# 18  Remember what I said just a moment ago. If it ...
# 19  Well, we have 105 empowerment zones and enterp...
# 20  Well, the bottom line is we have to stop expor...
# 21  Well, how about this for a government reform p...
# 22  Senator Bentsen is the number one PAC raiser. ...
# 23  The way we’re going to reduce this budget defi...
# 24  It would be rather difficult to cover them in ...
# 25  Your party doesn’t say it. Your party wants to...
# 26  Hillary and I also agree that the establishmen...
# 27  The — the safe zones would have to be — as the...
# 28  But for me, I would tell you that for me the s...
# 29  Well, the situation in Syria is catastrophic. ...
# 30  Well, first of all, I think Governor Romney’s ...
# 31  And so part of leadership and governing is bot...
# 32  Let’s not forget that they came in with one-pa...
# 33  And this isn’t — this isn’t going to be necess...
# 34  John McCain, in referring to the fundamental o...
# 35  I think the American public has the stomach fo...
# 36  … tough decisions. I want to get to Medicare i...
# 37  Well, Americans have gotten to know Sarah Pali...
# 38  That answer almost made me want to scowl. He k...
# 39  The vice president just said that we should fo...
# 40  The minute we have bilateral talks, the six-pa...
# 41  You’re absolutely right. There’s too much part...
# 42  Very current and difficult question. I’ve been...
# 43  I do. I do think this, though. When it comes t...
# 44  Well, I’ve been kind of a hard-liner on this i...
# 45  I don’t want to jump in. I may have been misle...
# 46  I’m not quite through. Let me finish. I talked...
# 47  We’ve got a bumper crop this year. But that’s ...
# 48  There were several off-the-subject quaffers in...
# 49  Well, with all due respect, Jim, there are nin...
#
# [50 rows x 21 columns]

# %%
df.at[49, 'Host Question']
# Out:
# 'Dimension 6 - Negative Pole - t002406 - Host Question: Mr. Kemp, do we have a serious race problem in the United States right now?'

# %%
print(df.at[49, 'Dimension Description'])
# Out:
# Dimension 6 - Negative Pole - t002406 - Dimension Description:
# The opposite ideological components would reflect an emphasis on openness, social investment, global cooperation, and decentralized decision-making, valuing collective well-being over rigid governmental control. Here’s how the reverse ideologies might look:
# 1. **Governmental Flexibility and Social Investment**: Instead of strict oversight and fiscal conservatism, this ideology favors a flexible, responsive government that prioritizes social investment over budgetary restrictions. It supports proactive spending in social programs, environmental initiatives, and public welfare, emphasizing adaptability over rigid accountability and a willingness to take financial risks for long-term social benefits.
# 2. **Global Engagement and Cooperative Security**: This perspective values diplomacy and multilateral cooperation over protectionism and military assertiveness. It advocates for international partnerships to address security issues, focusing on negotiation and peace-building with other nations, including traditional adversaries. Rather than imposing sanctions or military interventions, it seeks to address global challenges through collaboration and mutual understanding.
# 3. **Progressive Economic Policy**: In contrast to conservative economic values, this view supports active government involvement in the economy. It favors progressive taxation, increased government spending on social welfare, and programs aimed at reducing inequality. There’s an emphasis on reducing reliance on market forces alone, viewing government assistance and spending as essential for a balanced and fair economy.
# 4. **Idealism in Governance**: This ideology promotes value-based governance with an emphasis on ideals such as equity, justice, and inclusivity, even if the results are not immediately measurable. It prioritizes long-term social change and transformation, valuing participatory, inclusive approaches over results-driven pragmatism, even if they require broader shifts in societal structures.
# 5. **Nonpartisanship and Inclusive Governance**: Rather than strict partisanship, this pole emphasizes the importance of transcending political identities to work collaboratively. It values nonpartisan approaches, where policies are evaluated on their social benefits rather than ideological alignment. It downplays party identity in favor of inclusive, collective governance that reflects diverse societal interests and voices.
# 6. **Community-Centered Crisis Response**: This viewpoint emphasizes grassroots, community-led responses to crises rather than top-down leadership. It advocates for empowering local organizations, community leaders, and civic groups to address challenges collaboratively, focusing on shared decision-making and public input in times of crisis. The goal is to build resilient communities through cooperation rather than relying on authoritative, decisive moves from national leaders.
# In summary, this reversed dimension would emphasize **flexibility in government, global cooperation, progressive economic involvement, ideal-driven governance, nonpartisan inclusivity, and community empowerment in crisis management**. It reflects a philosophy of open governance, social responsibility, and collective solutions over nationalistic, security-focused, and fiscally conservative approaches.

# %% [markdown]
# ### Querying ChatGPT

# %%
# Setting up logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler(f"{output_directory}/chatgpt_processing.log"),
        logging.StreamHandler()
    ]
)

# Loading all environment variables from `.env` into `os.environ`
load_dotenv()

# Importing the required programme variables from the environment
openai.api_key = os.environ.get('OPENAI_API_KEY', '')
assert openai.api_key

# Defining a function to query ChatGPT with exponential backoff
def get_completion(prompt, model='gpt-4o', max_retries=5):
    client = openai.OpenAI()
    messages = [{'role': 'user', 'content': prompt}]
    for attempt in range(max_retries):
        try:
            response = client.chat.completions.create(
                model=model,
                messages=messages,
                temperature=0
            )
            return response.choices[0].message.content
        except openai.error.RateLimitError as e:
            wait_time = 2 ** attempt  # Exponential backoff
            logging.warning(f"Rate limit exceeded. Retrying in {wait_time} seconds...")
            time.sleep(wait_time)
        except Exception as e:
            logging.error(f"Error querying ChatGPT: {e}")
            return None
    logging.error("Max retries exceeded.")
    return None

# Defining a function to process text using ChatGPT
def process_text(text, prompt_template):
    paragraphs = text.split('\n')  # Split text into paragraphs
    processed_paragraphs = []
    for paragraph in paragraphs:
        prompt = prompt_template + paragraph
        try:
            processed_paragraph = get_completion(prompt)
            if processed_paragraph:
                processed_paragraphs.append(processed_paragraph)
            else:
                processed_paragraphs.append(paragraph)  # Keep original if there's an error
        except Exception as e:
            print(f"Error processing paragraph: {e}")
            processed_paragraphs.append(paragraph)  # Keep original if there's an error
    return '\n'.join(processed_paragraphs)

# Applying the function to the 'Text' column with progress indication
processed_texts = []
for index, row in tqdm(df.iterrows(), total=len(df), desc='Processing texts'):
    # Defining the ChatGPT prompt template
    prompt_template = chatgpt_prompt + '\n' + row['Dimension Description'] + '\n'
    
    # Processing text
    processed_texts.append(process_text(row['Host Question'], prompt_template))

df['Text ChatGPT'] = processed_texts
# Out:
# Processing texts:   0%|          | 0/50 [00:00<?, ?it/s]2024-11-19 15:33:40,409 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:   2%|▏         | 1/50 [00:07<05:43,  7.01s/it]2024-11-19 15:33:45,261 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:   4%|▍         | 2/50 [00:11<04:35,  5.74s/it]2024-11-19 15:33:50,897 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:   6%|▌         | 3/50 [00:17<04:27,  5.69s/it]2024-11-19 15:33:57,272 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:   8%|▊         | 4/50 [00:23<04:34,  5.96s/it]2024-11-19 15:34:01,087 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  10%|█         | 5/50 [00:27<03:53,  5.19s/it]2024-11-19 15:34:05,517 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  12%|█▏        | 6/50 [00:32<03:36,  4.93s/it]2024-11-19 15:34:12,863 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  14%|█▍        | 7/50 [00:39<04:05,  5.72s/it]2024-11-19 15:34:18,499 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  16%|█▌        | 8/50 [00:45<03:59,  5.69s/it]2024-11-19 15:34:25,162 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  18%|█▊        | 9/50 [00:51<04:05,  6.00s/it]2024-11-19 15:34:30,870 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  20%|██        | 10/50 [00:57<03:56,  5.91s/it]2024-11-19 15:34:37,211 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  22%|██▏       | 11/50 [01:03<03:55,  6.04s/it]2024-11-19 15:34:43,542 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  24%|██▍       | 12/50 [01:10<03:52,  6.13s/it]2024-11-19 15:34:50,647 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  26%|██▌       | 13/50 [01:17<03:57,  6.42s/it]2024-11-19 15:34:56,944 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  28%|██▊       | 14/50 [01:23<03:49,  6.39s/it]2024-11-19 15:35:02,173 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  30%|███       | 15/50 [01:28<03:31,  6.04s/it]2024-11-19 15:35:05,777 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  32%|███▏      | 16/50 [01:32<03:00,  5.30s/it]2024-11-19 15:35:13,065 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  34%|███▍      | 17/50 [01:39<03:14,  5.90s/it]2024-11-19 15:35:20,325 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  36%|███▌      | 18/50 [01:46<03:21,  6.31s/it]2024-11-19 15:35:26,321 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  38%|███▊      | 19/50 [01:52<03:12,  6.21s/it]2024-11-19 15:35:36,092 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  40%|████      | 20/50 [02:02<03:38,  7.28s/it]2024-11-19 15:35:40,691 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  42%|████▏     | 21/50 [02:07<03:07,  6.48s/it]2024-11-19 15:35:48,898 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  44%|████▍     | 22/50 [02:15<03:15,  7.00s/it]2024-11-19 15:35:55,810 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  46%|████▌     | 23/50 [02:22<03:08,  6.97s/it]2024-11-19 15:36:02,033 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  48%|████▊     | 24/50 [02:28<02:55,  6.75s/it]2024-11-19 15:36:08,460 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  50%|█████     | 25/50 [02:35<02:46,  6.65s/it]2024-11-19 15:36:16,342 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  52%|█████▏    | 26/50 [02:42<02:48,  7.02s/it]2024-11-19 15:36:22,463 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  54%|█████▍    | 27/50 [02:49<02:35,  6.75s/it]2024-11-19 15:36:27,900 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  56%|█████▌    | 28/50 [02:54<02:19,  6.36s/it]2024-11-19 15:36:32,680 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  58%|█████▊    | 29/50 [02:59<02:03,  5.88s/it]2024-11-19 15:36:38,789 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  60%|██████    | 30/50 [03:05<01:59,  5.95s/it]2024-11-19 15:36:47,835 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  62%|██████▏   | 31/50 [03:14<02:10,  6.88s/it]2024-11-19 15:36:57,423 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  64%|██████▍   | 32/50 [03:24<02:18,  7.69s/it]2024-11-19 15:37:06,533 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  66%|██████▌   | 33/50 [03:33<02:17,  8.12s/it]2024-11-19 15:37:10,855 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  68%|██████▊   | 34/50 [03:37<01:51,  6.98s/it]2024-11-19 15:37:17,271 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  70%|███████   | 35/50 [03:43<01:42,  6.81s/it]2024-11-19 15:37:21,674 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  72%|███████▏  | 36/50 [03:48<01:25,  6.09s/it]2024-11-19 15:37:27,764 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  74%|███████▍  | 37/50 [03:54<01:19,  6.09s/it]2024-11-19 15:37:34,888 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  76%|███████▌  | 38/50 [04:01<01:16,  6.40s/it]2024-11-19 15:37:40,602 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  78%|███████▊  | 39/50 [04:07<01:08,  6.19s/it]2024-11-19 15:37:44,768 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  80%|████████  | 40/50 [04:11<00:55,  5.59s/it]2024-11-19 15:37:50,212 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  82%|████████▏ | 41/50 [04:16<00:49,  5.54s/it]2024-11-19 15:37:58,375 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  84%|████████▍ | 42/50 [04:24<00:50,  6.33s/it]2024-11-19 15:38:03,813 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  86%|████████▌ | 43/50 [04:30<00:42,  6.06s/it]2024-11-19 15:38:08,272 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  88%|████████▊ | 44/50 [04:34<00:33,  5.58s/it]2024-11-19 15:38:12,201 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  90%|█████████ | 45/50 [04:38<00:25,  5.09s/it]2024-11-19 15:38:16,583 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  92%|█████████▏| 46/50 [04:43<00:19,  4.87s/it]2024-11-19 15:38:31,068 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  94%|█████████▍| 47/50 [04:57<00:23,  7.76s/it]2024-11-19 15:38:39,128 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  96%|█████████▌| 48/50 [05:05<00:15,  7.85s/it]2024-11-19 15:38:44,407 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts:  98%|█████████▊| 49/50 [05:11<00:07,  7.08s/it]2024-11-19 15:38:51,674 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing texts: 100%|██████████| 50/50 [05:18<00:00,  6.37s/it]

# %% [markdown]
# #### Exporting to a file

# %%
df.to_json(f"{output_directory}/{data_set}-ChatGPT.jsonl", orient='records', lines=True)

# %%
df.to_excel(f"{output_directory}/{data_set}-ChatGPT.xlsx", index=False)

# %% [markdown]
# #### Exporting each text processed by ChatGPT to individual files for inspection

# %%
for index, row in df.iterrows():
    # Constructing the file name based on row data and index
    file_name = f"{output_directory}/{row['Dimension']}_{row['Pole']}_{index}_{row['File']}_chatgpt.txt"
    
    # Writing the 'Host Question' and 'Text ChatGPT' content to the file
    with open(file_name, 'w', encoding='utf-8') as file:
        file.write(row['Host Question'] + '\n\n' + row['Text ChatGPT'])
